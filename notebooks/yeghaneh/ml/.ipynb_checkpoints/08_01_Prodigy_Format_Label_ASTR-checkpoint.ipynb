# %% [markdown]
# # Regex and Prodigy (LABEL: ASTR)

# %% [markdown]
# <font size= "3">
# Annotation of entities for sentences based on prodigy's format for different labels for further usage in Machine learning. Prodigy is an annotation tool based on spaCy. Please see here:
#     </p>
#   <a href="https://prodi.gy/ "> Prodigy </a>
# <font 3>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import re
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import spacy 
import re
from prodigy.util import write_jsonl

# %% [markdown]
# ## Read the Data

# %%
importVersion = '013'

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)# Put the path of the data in your local machine here, consider the letter "r" before the path
dfAstroNova = pd.read_pickle(path)

# %%
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAstroNova.head(5)
# Out:
#                                                 html  \
# 0                                  <p>Appendix B</p>
# 1  <p><span class="anchor" id="bookmark0"></span>...
# 2  <p>by Yaakov Zik <span style="font-variant: sm...
# 3  <p><span class="anchor" id="bookmark1"></span>...
# 4                              <p>General notes:</p>
#
#                                                 text links italic     chapter  \
# 0                                         Appendix B    []     []  appendix b
# 1          On the Table of Oppositions in Chapter 15    []     []  appendix b
# 2                             by Yaakov Zik Table i:    []     []  appendix b
# 3  Initial positions of Mars in Chapter 15 comput...    []     []  appendix b
# 4                                     General notes:    []     []  appendix b
#
#   graphic table marginal                                          sentences  \
# 0      []    []       []                                       [Appendix B]
# 1      []    []       []        [On the Table of Oppositions in Chapter 15]
# 2      []    []       []                           [by Yaakov Zik Table i:]
# 3      []    []       []  [Initial positions of Mars in Chapter 15 compu...
# 4      []    []       []                                   [General notes:]
#
#                                               tagged
# 0                    [[(Appendix, None), (B, None)]]
# 1  [[(On, None), (the, None), (Table, None), (of,...
# 2  [[(by, None), (Yaakov, None), (Zik, None), (Ta...
# 3  [[(Initial, None), (positions, None), (of, Non...
# 4                 [[(General, None), (notes, None)]]

# %%
len(dfAstroNova)
# Out:
# 1605

# %%
len(dfAstroNova['tagged'] )
# Out:
# 1605

# %% [markdown]
# ### Read the Sentences

# %%
df=dfAstroNova.sentences

# %%
texts=[]
for sen in dfAstroNova.sentences:
    texts +=sen

# %%
texts[0:10]
# Out:
# ['Appendix B',
#  'On the Table of Oppositions in Chapter 15',
#  'by Yaakov Zik Table i:',
#  'Initial positions of Mars in Chapter 15 computed with Guide 9 using JPL DE430.',
#  'General notes:',
#  "The time is measured from midnight; Gregorian dates are obtained by adding 10 days to Kepler's dates.",
#  'The dates are given in old style.',
#  'Geographical coordinates: Uraniborg 12 41 46 E, 55 54 30 N [50m]; Wandesburg (Wandsbek-Hamburg) 10 05 53 E, 53 35 10 N [15m]; Prague 14 26 E, 53 35 10 N [250m].',
#  'The longitudes are given in geocentric ecliptic coordinates.',
#  '1 2345']

# %% [markdown]
# ## Annotation Based on Consistant format with Prodigy

# %% [markdown]
# <fig size= 3>
# Prodigy accept a specific format; a JSONL format (newline-delimited JSON). Entities and other highlighted spans of text can be defined in the "spans" property. A example could look like this dictionary:
# </p>
# text': 'On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15.',
#   'spans': [{'start': 22, 'end': 29, 'label': 'TIME'}]}
# </p>
# which start and end's numbers refer to the position of entitiy  in the sentence. (here PARA)
#
#
# <fig size>

# %%
label = "PARA"   
texts = texts  
regex_patterns = [
re.compile(r'[A-Z]{3},?|[A-Z]{3}{\.}?|A-Z]{3}\)?|[A-Z]{4},?|[A-Z]{4}{\.}?|A-Z]{4}\)?')
                                          ]

examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)              

write_jsonl("NER_PARA_01.jsonl", examples)

# %% [markdown]
# ## See Misaligned Tokens

# %% [markdown]
# <fig size= 3>
# This step is very important, since if Pordigy faces with Misaligned tokens, we can see that before and try to adjust regex accordingly
# <fig size>

# %%
nlp = spacy.load("en_core_web_sm")  
for example in examples:  
    doc = nlp(example["text"])
    for span in example["spans"]:
        char_span = doc.char_span(span["start"], span["end"])
        if char_span is None:  
            print("Misaligned tokens", example["text"], span)
# Out:
# Misaligned tokens COMPUTED WITH GUIDE 9 USING JPL DE43O. {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens COMPUTED WITH GUIDE 9 USING JPL DE43O. {'start': 3, 'end': 6, 'label': 'PARA'}
# Misaligned tokens COMPUTED WITH GUIDE 9 USING JPL DE43O. {'start': 9, 'end': 12, 'label': 'PARA'}
# Misaligned tokens COMPUTED WITH GUIDE 9 USING JPL DE43O. {'start': 14, 'end': 17, 'label': 'PARA'}
# Misaligned tokens COMPUTED WITH GUIDE 9 USING JPL DE43O. {'start': 22, 'end': 25, 'label': 'PARA'}
# Misaligned tokens as here ABCE, FMNG cutting the equator AB in CN), part of them north and part south. {'start': 8, 'end': 11, 'label': 'PARA'}
# Misaligned tokens as here ABCE, FMNG cutting the equator AB in CN), part of them north and part south. {'start': 14, 'end': 17, 'label': 'PARA'}
# Misaligned tokens Slower still than this, slowest of all the stars, is the moon, since after setting with the sun today (at A, the moon being at F), it lags by an appreciable interval (EG) tomorrow when the sun sets (at E, the whole heaven and the moon along with it having made a circuit around the earth along FMNOG). {'start': 294, 'end': 297, 'label': 'PARA'}
# Misaligned tokens For example, if the sun at A along with a fixed star at H had been released from the same starting line AH on the previous day, so as to traverse BCDE and arrive at P while the fixed star traversed HLK and arrived at I, the sun, in the space of one day, would have retrogressed through the interval AP. {'start': 146, 'end': 149, 'label': 'PARA'}
# Misaligned tokens Let the plane of the ecliptic be ACDB, the plane of Mars’s orbit AEFB, and let them intersect one another in AB. {'start': 33, 'end': 36, 'label': 'PARA'}
# Misaligned tokens Let the plane of the ecliptic be ACDB, the plane of Mars’s orbit AEFB, and let them intersect one another in AB. {'start': 65, 'end': 68, 'label': 'PARA'}
# Misaligned tokens VIII. {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens And in the quadrilateral DEFG (if, indeed, it is inscribed in a circle, which is one of the hypotheses here), it is a consequence that two opposite angles (as GFE, GDE) taken together are equal to the sum of two right angles. {'start': 25, 'end': 28, 'label': 'PARA'}
# Misaligned tokens And so that point on the eccentric whence originates the eccentricity of Mars and all the planets (which is here considered to be on the line of the sun's mean motion, following earlier practitioners) does not go around on that circle DC about whose center A it makes equal angles in equal times, but on the circle HTES whose center lies in the direction opposite the center of the sun's eccentric B, as has thus far become roughly clear from the lines themselves. {'start': 315, 'end': 318, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 5, 'end': 8, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 10, 'end': 13, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 16, 'end': 19, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 19, 'end': 22, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 28, 'end': 31, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 37, 'end': 40, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 40, 'end': 43, 'label': 'PARA'}
# Misaligned tokens FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS {'start': 43, 'end': 46, 'label': 'PARA'}
# Misaligned tokens CHAPTER 3 {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens CHAPTER 3 {'start': 3, 'end': 6, 'label': 'PARA'}
# Misaligned tokens Now let CLOF be the orb of the moon, O the moon at opposition, C at conjunction, L, F at quadratures, and let CLOF remain for now a concentric described about the earth at T, and let it move in the direction OFCL. {'start': 8, 'end': 11, 'label': 'PARA'}
# Misaligned tokens Now let CLOF be the orb of the moon, O the moon at opposition, C at conjunction, L, F at quadratures, and let CLOF remain for now a concentric described about the earth at T, and let it move in the direction OFCL. {'start': 110, 'end': 113, 'label': 'PARA'}
# Misaligned tokens Now let CLOF be the orb of the moon, O the moon at opposition, C at conjunction, L, F at quadratures, and let CLOF remain for now a concentric described about the earth at T, and let it move in the direction OFCL. {'start': 208, 'end': 211, 'label': 'PARA'}
# Misaligned tokens Thus SCTO can properly be called the "diameter of power" since these two (T and S) are the sources of the entire motion. {'start': 5, 'end': 8, 'label': 'PARA'}
# Misaligned tokens CHAPTER 4 {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens CHAPTER 4 {'start': 3, 'end': 6, 'label': 'PARA'}
# Misaligned tokens Now, in the same manner, let the distances CA, GA, and so on, be set up, and the points A be connected by the conchoid*  A, A, A, A, drawn through the individual points (which are potentially infinite): the figure AACD will be equivalent to all the distances from A. For similarly the individual lines AG, AH have approximately made up the one parallelogram, except that the conchoid is not parallel to CD, but inclined to the radii GA, HA, EA, exactly as the distances are inclined to the circumference in the circle itself. {'start': 214, 'end': 217, 'label': 'PARA'}
# Misaligned tokens But EA is longer than EB, so that, if CA, GQ, HR, EB, IS, KL, DA, be taken, equal to lines determined by perpendiculars drawn from A to the lines between the points and B (as, in the circular diagram, the perpendicular AR is dropped to HB extended, defining HR which is shorter than HA), the figure between the conchoid AQRBSLA and CD would be quite equal to the figure CBBD. {'start': 320, 'end': 323, 'label': 'PARA'}
# Misaligned tokens But EA is longer than EB, so that, if CA, GQ, HR, EB, IS, KL, DA, be taken, equal to lines determined by perpendiculars drawn from A to the lines between the points and B (as, in the circular diagram, the perpendicular AR is dropped to HB extended, defining HR which is shorter than HA), the figure between the conchoid AQRBSLA and CD would be quite equal to the figure CBBD. {'start': 323, 'end': 326, 'label': 'PARA'}
# Misaligned tokens But EA is longer than EB, so that, if CA, GQ, HR, EB, IS, KL, DA, be taken, equal to lines determined by perpendiculars drawn from A to the lines between the points and B (as, in the circular diagram, the perpendicular AR is dropped to HB extended, defining HR which is shorter than HA), the figure between the conchoid AQRBSLA and CD would be quite equal to the figure CBBD. {'start': 370, 'end': 373, 'label': 'PARA'}
# Misaligned tokens For the conchoid would intersect BB at the line EA, and because BA at the top and bottom are equal, and BQ is equal to LB, BR to SB, and so on, the figures BBRQA and BBALS would therefore be congruent. {'start': 156, 'end': 159, 'label': 'PARA'}
# Misaligned tokens For the conchoid would intersect BB at the line EA, and because BA at the top and bottom are equal, and BQ is equal to LB, BR to SB, and so on, the figures BBRQA and BBALS would therefore be congruent. {'start': 166, 'end': 169, 'label': 'PARA'}
# Misaligned tokens One of these is added to, and the other subtracted from, the equal figures CBBE and EBBD, and therefore, the whole figure between AQRBSLA and CD is equal to that between BB and CD. {'start': 75, 'end': 78, 'label': 'PARA'}
# Misaligned tokens One of these is added to, and the other subtracted from, the equal figures CBBE and EBBD, and therefore, the whole figure between AQRBSLA and CD is equal to that between BB and CD. {'start': 84, 'end': 87, 'label': 'PARA'}
# Misaligned tokens One of these is added to, and the other subtracted from, the equal figures CBBE and EBBD, and therefore, the whole figure between AQRBSLA and CD is equal to that between BB and CD. {'start': 130, 'end': 133, 'label': 'PARA'}
# Misaligned tokens One of these is added to, and the other subtracted from, the equal figures CBBE and EBBD, and therefore, the whole figure between AQRBSLA and CD is equal to that between BB and CD. {'start': 133, 'end': 136, 'label': 'PARA'}
# Misaligned tokens Hence, the small area between the two conchoids AQRBSLA and AAAAAA is the measure of the excesses of the distances from A over the distances from B —and the standard of measure is the same as that by which the parallelogram is set equal to all the distances from B. {'start': 48, 'end': 51, 'label': 'PARA'}
# Misaligned tokens Hence, the small area between the two conchoids AQRBSLA and AAAAAA is the measure of the excesses of the distances from A over the distances from B —and the standard of measure is the same as that by which the parallelogram is set equal to all the distances from B. {'start': 51, 'end': 54, 'label': 'PARA'}
# Misaligned tokens Hence, the small area between the two conchoids AQRBSLA and AAAAAA is the measure of the excesses of the distances from A over the distances from B —and the standard of measure is the same as that by which the parallelogram is set equal to all the distances from B. {'start': 60, 'end': 63, 'label': 'PARA'}
# Misaligned tokens Hence, the small area between the two conchoids AQRBSLA and AAAAAA is the measure of the excesses of the distances from A over the distances from B —and the standard of measure is the same as that by which the parallelogram is set equal to all the distances from B. {'start': 63, 'end': 66, 'label': 'PARA'}
# Misaligned tokens [IIIb.] {'start': 1, 'end': 4, 'label': 'PARA'}
# Misaligned tokens So, when least arcs are in question, the one is compensated by the other, so that TNA and ODA are very nearly equal to the area GDNA. {'start': 128, 'end': 131, 'label': 'PARA'}
# Misaligned tokens But since the second and fourth could not be reconciled, while the force of these observations was great, because in each the planet was observed in quadrature with the sun, and in the quadrilateral AEKG all the sides and angles are about equal, I therefore settled it as follows. {'start': 199, 'end': 202, 'label': 'PARA'}
# Misaligned tokens VIII {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens XIII {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens If someone were to divide an ellipse AMC into any number of equal arcs, assigning to each individually its distance from N, while taking the areas AMN,  ABN, ABCNA in place of the sum of the distances on AM, AB, ABC, by Protheorem 10 he would bring about the same error that occured in Ch. {'start': 158, 'end': 161, 'label': 'PARA'}
# Misaligned tokens Let CBAD be the ecliptic, A, C the nodes; {'start': 4, 'end': 7, 'label': 'PARA'}
# Misaligned tokens Now since we are supposing this axis to remain equidistant from itself throughout its circuit, it will happen that as the body moves from the ascending node C to the northern limit B, the axis IK of the body, which initially, at the node C, was tangent as it were to the imaginary circle of its circulation through CNAO, later intersects it at right {'start': 315, 'end': 318, 'label': 'PARA'}
# Misaligned tokens But also, owing to a certain amount of declination from the royal road2 CBA, this axis had thus far been enticing the body of the planet to leave that path in the direction of N, towards which it had turned the preceding part K. Now, at the limits, although it has indeed remained inclined to the plane of the ecliptic CBS (for we have said that it remains equidistant from itself in all positions, and so once it is inclined to the plane of the ecliptic it will always be inclined), it nevertheless does not continue to decline from the royal road itself, that is, from the circumference of the plane of the ecliptic CBAD, once it is placed at GH. {'start': 618, 'end': 621, 'label': 'PARA'}
# Misaligned tokens This axis of inclination is somewhat like an oar, in that just as boatmen use oars to move from one bank to the other, the planet brings this about through the inclination of the axis,  moving it from north to south and back, while the river, that is, the immaterial species of the sun, proceeds along the direct path CBAD. {'start': 318, 'end': 321, 'label': 'PARA'}
# Misaligned tokens And if this plane be extended, it intersects the sphere of the fixed stars in the shape of a great circle, FEGH in the diagram of Chapter 13, because it intersects the plane of the ecliptic DC at the center of the world or the sun, A. To further convince yourself of this, you should consider that the points of intersection or nodes are in opposite positions about the center of the sun A, as you see in the diagram. {'start': 107, 'end': 110, 'label': 'PARA'}
# Misaligned tokens What wonder, then, if the moon keeps the limits of its latitude constant with respect to the changeable ecliptic HK, beneath which lies the terrestrial circle, while the other planets do so with respect to some other invariable circle, such as LOIM? {'start': 244, 'end': 247, 'label': 'PARA'}
# Misaligned tokens It is therefore granted that Mars's orbit is inclined at a constant angle to some circle that maintains its position beneath the same fixed stars, such as  LOIM. {'start': 156, 'end': 159, 'label': 'PARA'}
# Misaligned tokens This only follows, however, if we grant that the nodes of Mars and the nodes of the earth, that is, the intersections of these orbits with the invisible circle LOIM, are not always carried over the same intervals in the heavens, some being faster than others. {'start': 160, 'end': 163, 'label': 'PARA'}
# Misaligned tokens For since the equator maintains a constant inclination to this invisible circle LOIM, while the ecliptic is meanwhile moved, the declination of the equator from the ecliptic is consequently perceived to be changeable. {'start': 80, 'end': 83, 'label': 'PARA'}
# Misaligned tokens THIS, THEN, IS BRAHE’S TABLE {'start': 0, 'end': 3, 'label': 'PARA'}
# Misaligned tokens THIS, THEN, IS BRAHE’S TABLE {'start': 6, 'end': 9, 'label': 'PARA'}
# Misaligned tokens THIS, THEN, IS BRAHE’S TABLE {'start': 15, 'end': 18, 'label': 'PARA'}
# Misaligned tokens THIS, THEN, IS BRAHE’S TABLE {'start': 23, 'end': 26, 'label': 'PARA'}
# Misaligned tokens For the whole plane CEHG is beneath the arc EC. {'start': 20, 'end': 23, 'label': 'PARA'}

# %%
examples [1500:1900]  # here we can search for Misaligned Tokens and try to find a remedy by regex
# Out:
# [{'text': "For Mars, the magnitude of QAF or RAE is observed to be about 9’, while SAG or TAD is about 28'.",
#   'spans': [{'start': 27, 'end': 31, 'label': 'PARA'},
#    {'start': 34, 'end': 38, 'label': 'PARA'},
#    {'start': 72, 'end': 76, 'label': 'PARA'},
#    {'start': 79, 'end': 83, 'label': 'PARA'}]},
#  {'text': 'Now as a third step, let this hypothesis too be corrected.',
#   'spans': []},
#  {'text': "As this can happen in a variety of ways (specifically, by a reciprocation of the point C along the line CA), we are not prevented by any scruple from keeping the point of uniform motion C fixed at distance CA, on account of the angle KAV, and also keeping the planet's path circular.",
#   'spans': [{'start': 234, 'end': 239, 'label': 'PARA'}]},
#  {'text': "These three, taken by choice and not forced by demonstration, will compel us to move the center of the eccentric downwards to B from the point of uniform motion C. Hence, HI is substituted for MN, and the body of the planet departs from the points Q, R, S, T, nevertheless remaining on the lines CQ, CR, CS, CT (because the measure of time stays at C), and arrives at the points marked F, E, G, D. And QF, ER, SG, TD would be such as to make QAF, EAR 9’ and SAG, TAD 28'.",
#   'spans': [{'start': 442, 'end': 447, 'label': 'PARA'},
#    {'start': 447, 'end': 451, 'label': 'PARA'},
#    {'start': 458, 'end': 463, 'label': 'PARA'},
#    {'start': 463, 'end': 467, 'label': 'PARA'}]},
#  {'text': 'With this done, that error at the eighths of the period will also be absorbed, and the hypothesis will exhibit the longitude perfectly accurately at eight places.',
#   'spans': []},
#  {'text': 'Thus if again some error remains, it will be at the sixteenths of the period, the points in between.',
#   'spans': []},
#  {'text': 'Also, since this third eccentric HI is equivalent to the first at positions AM, AP, as well as to the second at the additional positions AK, AL, it introduces no new error.',
#   'spans': []},
#  {'text': 'And because the error of the second was greatest at the eighths of the period, and this is now absorbed, at the sixteenths there will therefore be a much smaller error remaining from the old error.',
#   'spans': []},
#  {'text': "Let us estimate it proportionally: just as the error of the first eccentric was 10½ ° while that of the second was 9' or 28', that is, one seventieth or one twenty-fifth of the former, let us now make the errors of the second that many  times the errors of the third.",
#   'spans': []},
#  {'text': 'Plainly, already at the sixteenths of the period, we will have driven the business down to within the limits of observational accuracy.',
#   'spans': []},
#  {'text': 'It is at least now clear to what extent and in what manner the truth may follow from false principles: whatever is false in these hypotheses is specific to them and can be absent, while whatever endows truth with necessity is in general aspect wholly true and nothing else ^1.',
#   'spans': []},
#  {'text': 'Further, as these false principles are fitted only to fixed positions throughout the whole circle, so the truth does not invariably follow outside those very positions, except to the extent that happens in this procedure, that the difference can no longer be appraised by the acuteness of the senses.',
#   'spans': []},
#  {'text': 'Also, this same dullness of the senses hides the following additional small error which remains at the eighths of the period.',
#   'spans': []},
#  {'text': 'That there is such a remainder I prove thus:', 'spans': []},
#  {'text': 'Once again, let a perfect eccentric be described about B so that BD, BE, BF, BG are equal, and let us have made BC such that the angle QAF is of the required magnitude.',
#   'spans': [{'start': 135, 'end': 139, 'label': 'PARA'}]},
#  {'text': 'Now it is not likewise left to our discretion how great we want angle SAG to be, since it will be completely determined.',
#   'spans': [{'start': 70, 'end': 74, 'label': 'PARA'}]},
#  {'text': 'From A draw a perpendicular to QT, and let this be AZ.',
#   'spans': []},
#  {'text': 'Now, as above, let AC be 18,564 where CQ is 100,000.', 'spans': []},
#  {'text': 'And because ACZ is 45°, AZ or ZC will be 13,127 (both in the same units).',
#   'spans': [{'start': 12, 'end': 16, 'label': 'PARA'}]},
#  {'text': 'Therefore, ZQ is 113,127, and AQZ 6° 37\' 5", and QAZ 83° 22\' 55", whose tangent is 864092 ^2.',
#   'spans': [{'start': 30, 'end': 34, 'label': 'PARA'},
#    {'start': 49, 'end': 53, 'label': 'PARA'}]},
#  {'text': "Now let FAZ be taken as 9' less: its tangent FZ will be 844900 ^3.",
#   'spans': [{'start': 8, 'end': 12, 'label': 'PARA'}]},
#  {'text': 'But where AZ is 13,127, ZF will be 110,910.', 'spans': []},
#  {'text': 'Therefore, QF will be 2217.', 'spans': []},
#  {'text': 'Now QF is larger than TD, which I prove thus: QT is the diameter of the circle, and is therefore equal to the two semidiameters FB, BD taken together.',
#   'spans': []},
#  {'text': 'But BF, BD taken together are greater than FD.', 'spans': []},
#  {'text': 'Therefore, QT is also greater than FD.', 'spans': []},
#  {'text': 'Let the common part FT be subtracted.', 'spans': []},
#  {'text': 'The remainder QF is then greater than TD.', 'spans': []},
#  {'text': 'And yet, over and above what is required, we shall allow them to be equal.',
#   'spans': []},
#  {'text': 'Let CZ, 13,127, be subtracted from CT, so as to leave ZT, 86,873.',
#   'spans': []},
#  {'text': 'Now from AZ, AT, ATZ is known, and it is 8° 35\' 33".',
#   'spans': [{'start': 17, 'end': 21, 'label': 'PARA'}]},
#  {'text': 'So ZAT is 81° 24\' 27".',
#   'spans': [{'start': 3, 'end': 7, 'label': 'PARA'}]},
#  {'text': 'And because ZT is 86,873, I shall add to it a magnitude equal to QF, as if it were TD, namely, 2217.',
#   'spans': []},
#  {'text': 'This will makes ZD 89,090.', 'spans': []},
#  {'text': 'But where AZ is 100,000, ZD will become the tangent of the angle ZAD, 686,291.',
#   'spans': [{'start': 65, 'end': 70, 'label': 'PARA'}]},
#  {'text': 'Thus this angle is 81° 42\' 35".', 'spans': []},
#  {'text': 'But ZAT was 81° 24\' 27".',
#   'spans': [{'start': 4, 'end': 8, 'label': 'PARA'}]},
#  {'text': 'Therefore TAD, or SAG, is less than the difference, 18\' 8", since TD is less than 2217.',
#   'spans': [{'start': 10, 'end': 15, 'label': 'PARA'},
#    {'start': 18, 'end': 23, 'label': 'PARA'}]},
#  {'text': 'This then is the required angle TAD, which ought to have been 27⅗’.',
#   'spans': [{'start': 32, 'end': 37, 'label': 'PARA'}]},
#  {'text': "And so if you make QAF 12' instead of 9', TAD becomes 24'.",
#   'spans': [{'start': 19, 'end': 23, 'label': 'PARA'},
#    {'start': 42, 'end': 46, 'label': 'PARA'}]},
#  {'text': 'And in both places the planet is made to be 3 minutes higher than it should be.',
#   'spans': []},
#  {'text': 'The equation therefore will be seen to be too large, and thus the eccentricity [of the equant] is too large.',
#   'spans': []},
#  {'text': 'It will straightaway be diminished, then, so that the planet is about 1½’ lower at the lines AK, AL, and the same amount (that is, 1½’ ) higher at D, E, F, and G ^4.',
#   'spans': []},
#  {'text': 'This mutual tempering of various influences causes one error to compensate for another, brings the calculation within the limits of observational precision, and makes it impossible to perceive the falsity of this specific hypothesis.',
#   'spans': []},
#  {'text': 'And so this sly courtesan cannot gloat over the dragging of truth (a most chaste maiden) into her bordello.',
#   'spans': []},
#  {'text': "Any honest woman following the lead of this prostitute would stay closely in her tracks owing to the narrowness of the streets and the press of the crowd, and the stupid, bleary-eyed professors of the subtleties of logic, who cannot tell a candid appearance from a shameless one,  judge her to be the prostitute's maidservant.",
#   'spans': []},
#  {'text': 'This is without doubt the reason for the remaining discrepancies of one or two minutes in Ch.',
#   'spans': []},
#  {'text': '18, in Cancer, Leo, Scorpio, and several other places.',
#   'spans': []},
#  {'text': 'But the error is not easy to see, since the observations used do not fall at the apsides and at the quarters and eighths of the period.',
#   'spans': []},
#  {'text': 'Conclusion of Part II', 'spans': []},
#  {'text': "Up to the present, the hypothesis accounting for the first inequality (in which Brahe and Copernicus are in agreement, both differing somewhat in form from Ptolemy) has been presented using the sun's mean motion, which all three authors had substituted for the sun's apparent motion.",
#   'spans': []},
#  {'text': "Thereafter, it was shown that whether we follow the sun's apparent motion and the hypothesis found in Ch.",
#   'spans': []},
#  {'text': "16, or the sun's mean motion and the hypothesis proposed in Ch.",
#   'spans': []},
#  {'text': "8 according to Brahe's revision, in both instances there result false distances of the planet from the center, whether of the sun (for Copernicus and Brahe) or of the world (for Ptolemy).",
#   'spans': []},
#  {'text': 'Consequently, what we had previously constructed from the Brahean observations we have later in turn destroyed using other observations of his.',
#   'spans': []},
#  {'text': 'This was the necessary consequence of our having followed (in imitation of previous theorists) several things that were plausible but really false.',
#   'spans': []},
#  {'text': 'And this much of the work is dedicated to this imitation of previous theorists, with which I am concluding this second part of the Commentaries.',
#   'spans': []},
#  {'text': 'Chapter 22', 'spans': []},
#  {'text': 'The epicycle, or annual orb, is not equally situated about the point of equality of motion.',
#   'spans': []},
#  {'text': 'This, then, is the way our predecessors measured the first inequality.',
#   'spans': []},
#  {'text': "With this calculation established, which would represent the planet's eccentric position at any desired moment, they next turned to exploring the second inequality (which depends upon the sun), comparing the observed or apparent position with that which the eccentric and the planet's first inequality alone would assign.",
#   'spans': []},
#  {'text': 'When I was on this same path and was confronted with this equivocal fork in the road (in Chapters 19 and 20 above), and the observations (most faithful guides) were seen to be at war with observations, I had to give thought to altering completely the way the path was set out, using the method which follows.',
#   'spans': []},
#  {'text': 'First, in this third part I shall approach the second inequality.',
#   'spans': []},
#  {'text': 'Here I shall use unquestionable observations to demonstrate, with either a confirmation or a refutation, all that I have hitherto supposed as principles but had doubts about.',
#   'spans': []},
#  {'text': 'Once this is found it will be like a key: the rest will be opened up.',
#   'spans': []},
#  {'text': 'Afterwards, in Part IV, I shall proceed to the first inequality.',
#   'spans': []},
#  {'text': 'In Chapter 22 of the Mysterium cosmographicum, when I was giving the physical cause of the Ptolemaic equant or of the Copernican-Tychonic second epicycle, I raised an objection against myself at the end of the chapter: if the cause I proposed were true, it ought to hold universally for all planets ^1.',
#   'spans': []},
#  {'text': 'But since the earth, one of the celestial bodies (for Copernicus), or the sun (for the rest) had not hitherto required this equant, I decided to leave that speculation open, until the matter were clearer to astronomers.',
#   'spans': []},
#  {'text': 'I nevertheless entertained a suspicion that this theory might perchance also have its equant.',
#   'spans': []},
#  {'text': 'After I gained the recognition of Tycho, this suspicion was confirmed in me.',
#   'spans': []},
#  {'text': 'For in a letter to me in Styria in 1598 Brahe said the following:',
#   'spans': []},
#  {'text': "The annual orb according to Copernicus, or the epicycle according to Ptolemy, does not appear always of the same size, in comparisons made to the eccentric, but introduces a perceptible alteration in all three superior planets, so much so that for Mars the angle of difference reaches one degree 45' ^2.",
#   'spans': []},
#  {'text': 'He also touched upon this point at the same time in the appendix to his Mechanica,3 an account of his studies.',
#   'spans': []},
#  {'text': 'Also, his words in volume I p.', 'spans': []},
#  {'text': '209 of his letters4 are not much different, where he states the opinion that as an effect of the solar eccentricity a certain amount of nonuniformity is also mixed in with the eccentric equations and the acronychal positions.',
#   'spans': []},
#  {'text': 'This is, in fact, refuted in Part I: it is not reflected in the acronychal positions, or at least very little.',
#   'spans': []},
#  {'text': 'But it appears that this needs to be understood through a certain correction regarding Mars at 90° from the sun.',
#   'spans': []},
#  {'text': "Now when I heard that the annual orb grows and shrinks, an inspiration said to me that this illusion arises thus: Copernicus's annual orb, or Ptolemy's epicycle, is not everywhere distant from that center about which by supposition it is sweeping out equal angles in equal times.",
#   'spans': []},
#  {'text': 'For what physical cause  could make the circuit of the center of the planetary system (Tychonic) or of the circuit of the earth (for Copernicus) or of the epicycle bearing the star (for Ptolemy) grow and shrink?',
#   'spans': []},
#  {'text': 'What, I ask, is this novelty unprecedented in astronomy, this unlikely absurdity?',
#   'spans': []},
#  {'text': "Wouldn't it seem more worthy of belief that the sun (for Copernicus) or the center of the planetary system (Tychonic) or the body of the planet (for Ptolemy) would in certain places be farther from, and in others nearer to, the selected point of uniform motion (at rest for Copernicus and Tycho, and moving around on the circumference of the eccentric for Ptolemy)—and this especially on the line of apsides?",
#   'spans': []},
#  {'text': 'And for this, that suspicion of mine arising from my Mysterium cosmographicum—that an equant might be introduced into the theory of the sun (or, as I call it, the theory of the Ptolemaic epicycle)—seemed to provide a convenient occasion.',
#   'spans': []},
#  {'text': "Let us suppose that the second inequality starts from the line of the sun's mean motion, as the practitioners have hitherto been pleased to hold (lest anyone hold suspect here my innovation of using the sun's apparent motion), and in the present diagram let the planet's eccentricity for Copernicus originate not from the sun's center A, but from the point C about which the earth's motion is supposed regular.",
#   'spans': []},
#  {'text': "But let that point C not be the center of the earth's orb DE but only of uniformity of motion, and let its distance from the sun A be greater than that of B, the center of the earth's orb ED.",
#   'spans': []},
#  {'text': 'I say that, these things being granted, such observations will be produced from which one might suspect the annual orb of growing and shrinking.',
#   'spans': []},
#  {'text': "Let a line CF be drawn from C perpendicular to DE, and let the star Mars be at F twice: once when the earth is at D and again when it is at E; and let F be joined with the points D and E. Now because C is the point of uniformity of the earth's motion on DE, FCD and FCE will be the anomaly of commutation, and (as we suppose) equal on both sides.",
#   'spans': [{'start': 258, 'end': 262, 'label': 'PARA'},
#    {'start': 266, 'end': 270, 'label': 'PARA'}]},
#  {'text': 'Now if CD and CE were equal (as has hitherto been thought) then the angles DFC and EFC, parallaxes of the orb, would be equal on both sides, for both anomalies of commutation.',
#   'spans': [{'start': 75, 'end': 79, 'label': 'PARA'},
#    {'start': 83, 'end': 88, 'label': 'PARA'}]},
#  {'text': 'But because CE is greater than CD, the angle CFE will also appear greater than the angle CFD.',
#   'spans': [{'start': 45, 'end': 49, 'label': 'PARA'},
#    {'start': 89, 'end': 93, 'label': 'PARA'}]},
#  {'text': 'Therefore, anyone not noticing that this growth occurs only at or about E, and that the contrary diminution occurs only at the contrary position D, will think that the entire annual orb sometimes gets larger, with radius CE, and sometimes smaller, with radius CD.',
#   'spans': []},
#  {'text': 'This is because such a person presupposes, along with astronomy as it has hitherto been practiced, that the point of equal motion C is at the same time also the center of the circle DE.',
#   'spans': []},
#  {'text': "In the Ptolemaic form, let the earth be at C, and the lines of the sun's mean motion be CK, CL, in place of DC and EC in the preceding Copernican arrangement.",
#   'spans': []},
#  {'text': 'And let the center about which the epicyclic motion is regular be at F, and IH be equal and parallel to ED so that, CI being drawn, it is parallel to DF and CH to  EF.',
#   'spans': []},
#  {'text': 'For when the earth (or the observer) is transferred to the center of the world C, as Ptolemy has it, Mars at F is likewise transferred to H. Similarly, owing to the translation of D to C, F is transferred to I. Now Ptolemy, thinking that the point F, about which the motion of the epicycle IH is uniform, is also the center of the epicycle IH, supposed FI and FH to be exactly equal.',
#   'spans': []},
#  {'text': 'Consequently, for both of the equated anomalies HFC as well as IFC (that is, at both 90° and 270°, in this diagram) he posited one and the same equation of the epicycle, namely, the equal angles HCF and ICF.',
#   'spans': [{'start': 48, 'end': 52, 'label': 'PARA'},
#    {'start': 63, 'end': 67, 'label': 'PARA'},
#    {'start': 195, 'end': 199, 'label': 'PARA'},
#    {'start': 203, 'end': 207, 'label': 'PARA'}]},
#  {'text': 'So if observation affirms that HCF is greater than ICF, then the center of the epicycle will not be at the point of uniform motion F, but at G, in the direction of H. Further, on the supposition that F be nevertheless considered the center of the epicycle, the epicycle will appear distinctly enlarged at anomaly 90° at H, and diminished at 270° at I, while in both instances Mars, in its eccentric position (that is, on the line CF), is in the same position with respect to the fixed stars.',
#   'spans': [{'start': 31, 'end': 35, 'label': 'PARA'},
#    {'start': 51, 'end': 56, 'label': 'PARA'}]},
#  {'text': "In the Tychonic form, let C remain the earth, DE the sun's circle with center B, but let the center of uniform motion be A. And let the lines along which the planet is seen (namely, CI and CH) be the same as in Ptolemy.",
#   'spans': []},
#  {'text': 'Accordingly, let HL, IK descend from H and I parallel to FC.',
#   'spans': []},
#  {'text': "In order that K and L be the center of the planetary system, let the center of its circuit be M, which is in the direction of the sun's perigee, so that the point M, the center of the circuit KL (in which is found the point from which Mars's eccentricity originates) descends as far below C as the point B, the true center of the sun's circuit (contrary to common opinion), descends below A, the putative center of the same circuit of the sun.",
#   'spans': []},
#  {'text': 'And let AC and BM be equal.', 'spans': []},
#  {'text': 'The line of equated motion on the eccentric (that is, KI, LH) will be parallel to itself after an integral number of returns of the planet.',
#   'spans': []},
#  {'text': "Therefore Tycho, thinking that the earth C is in the middle of the circuit KL bearing the planets' eccentrics, will make angles CIK, CHL equal when the angles of commutation CLH, CKI are equal.",
#   'spans': [{'start': 128, 'end': 133, 'label': 'PARA'},
#    {'start': 133, 'end': 137, 'label': 'PARA'},
#    {'start': 174, 'end': 179, 'label': 'PARA'},
#    {'start': 179, 'end': 183, 'label': 'PARA'}]},
#  {'text': "But if these are perceived to be unequal, CHL being the greater, CL will be longer than CK: and the orb KL, the deferent of the center of the system, will appear to grow at L and to shrink at K, because M, the center of the orb which is the planetary system's deferent, is not believed to be elsewhere than at the earth C, about whose center the motion of that orb is uniform.",
#   'spans': [{'start': 42, 'end': 46, 'label': 'PARA'}]},
#  {'text': "Now what greatly contributes to obscuring the true cause of this difference, namely, to freeing the sun's eccentricity from suspicion, is the fact that thereby*  the distance CK of the center of the system from the earth becomes short just where the distance CE of the sun from the earth becomes long; and conversely, that the former, CL, becomes long where the latter, CD, becomes short.",
#   'spans': []},
#  {'text': 'The reason why the apsides have thus been reversed is this.',
#   'spans': []},
#  {'text': "For Copernicus, the earth traverses the regions opposite the Tychonic sun and the Ptolemaic epicycle, and also DC, CE, the distances of the earth from the sun, of the sun from the earth, and of Mars H or I from the epicycle's center of uniform motion F, subtend angles of the same magnitude in all three forms of hypothesis.",
#   'spans': []},
#  {'text': 'Therefore, it also happens that the Copernican distances of the sun and the earth will be transferred to the opposite sides by Brahe and Ptolemy; that is, CE to CL or FH, and CD to CK or FI.',
#   'spans': []},
#  {'text': 'Next, in order either to confirm or undermine this speculation by observations, this is the road upon which I  set out.',
#   'spans': []},
#  {'text': "Since the sun's apogee is at 5½° Cancer, I enquired whether there might exist an observation in which Mars, reckoned by the first inequality, would be twice at 5½° Libra or Aries, while the sun would be at 5½° Cancer at one time, and then at 5½° Capricorn.",
#   'spans': []},
#  {'text': 'As it turns out, this is not possible within such a short space of time (20 or 30 years).',
#   'spans': []},
#  {'text': 'For the periodic motions of Mars and the sun are incommensurable, nor do they ever coincide at 90° from one another, or at opposition, after a certain number of complete periods, or quarter or half periods, of either.',
#   'spans': []},
#  {'text': 'I therefore had to choose the next best thing, which was to find many days throughout those 20 years on which the planet was observed, and in which the equated anomaly of commutation was 90° or 270° or nearly that much, with Mars at 6 Aries or Libra or thereabouts.',
#   'spans': []},
#  {'text': 'Afterwards, it was necessary to look up all those dates in the catalog of observations of Mars, so I could see whether it had been observed at those moments.',
#   'spans': []},
#  {'text': 'Had the indefatigable Tycho Brahe not observed Mars very frequently, the selection would have been so exclusive that I would not have been able to accomplish what I wished.',
#   'spans': []},
#  {'text': 'Now since Tycho put the apogee of Mars at 23½° Leo, while the required position of Mars, corrected by the eccentric equation, was 5½° Libra, an equated anomaly of 42° was required.',
#   'spans': []},
#  {'text': "And from his table, to an equated anomaly of 42° there corresponds an equation of 8° 15⅗'; therefore, a mean anomaly on the eccentric of 50° 16' was required, and through this I was shown twelve points in time in the twenty years between 1579 and 1600.",
#   'spans': []},
#  {'text': 'Thus, what had to be skillfully tracked down is whether for any of these times there was an equated anomaly of commutation that was at one time 90° and again 270°, or if the former were greater or less, the latter would be correspondingly less or greater.',
#   'spans': []},
#  {'text': 'One revolution of Mars has 687 days, and two of the sun have 730½.',
#   'spans': []},
#  {'text': 'The difference is 43½ days, to which corresponds 42° 54\' 23" of the sun\'s mean motion.',
#   'spans': []},
#  {'text': 'This, therefore, is how much the anomaly of commutation changes at the end of any revolution of Mars.',
#   'spans': []},
#  {'text': "Therefore, when in any two year period one seeks two anomalies of commutation that are equal, with Mars at the same eccentric position, each angle of commutation should be 21° 27'.",
#   'spans': []},
#  {'text': "Over four years 42° 54' is required; over six years, 64° 22'; over eight years, 85° 49'.",
#   'spans': []},
#  {'text': 'And we were supposing 90°, if it were possible.', 'spans': []},
#  {'text': 'Therefore, we had to look for our two observations eight years apart.',
#   'spans': []},
#  {'text': 'However, a team of two such observations is not to be found in the catalog of observations we had.',
#   'spans': []},
#  {'text': 'I next turned to the interval of six years, and found at length that from 1585 May 18 and 1591 January 22 suitable observations exist.',
#   'spans': []},
#  {'text': 'For they corresponded to 1585 May 30 at 5h and 1591 January 20 at 0h ^5.',
#   'spans': []},
#  {'text': "For both, the mean longitude of Mars was 6s 22° 43'.", 'spans': []},
#  {'text': 'The Tychonic equation was 9° 14\' 52", to be subtracted.',
#   'spans': []},
#  {'text': 'Therefore, Mars\'s eccentric position was 13° 28\' 16" Libra.',
#   'spans': []},
#  {'text': 'The equated commutation for 1585 was 8s 4° 23\' 30", by which it was shown,  Ptolemaic style, that the planet was 64° 23\' 30" beyond the perigee of the epicycle.',
#   'spans': []},
#  {'text': 'Similarly, the equated commutation for 1591 was 3s 25° 36\' 30", by which it was shown that the planet was 64° 23\' 30" before the perigee of the epicycle.',
#   'spans': []},
#  {'text': 'Therefore, both the angles of commutation, FCD and FCE (or CFI, CFH) in the diagram, are equal.',
#   'spans': [{'start': 43, 'end': 47, 'label': 'PARA'},
#    {'start': 51, 'end': 55, 'label': 'PARA'},
#    {'start': 59, 'end': 64, 'label': 'PARA'},
#    {'start': 64, 'end': 68, 'label': 'PARA'}]},
#  {'text': 'However, in 1585 the sun was in 18° Gemini, 18° before apogee, and in 1591 in 9° Aquarius, 33° beyond perigee, and this inequality could not be avoided.',
#   'spans': []},
#  {'text': 'Now to the observations: on 1585 May 18 at 10½h at night Mars was observed at 0° 50\' 45" Virgo with latitude 1° 19\' 30" north ^6.',
#   'spans': []},
#  {'text': "Magini puts it at 1° 5' Virgo,7 14' or 15' too much.", 'spans': []},
#  {'text': "Therefore, when on the 30th at 5h in the evening he puts it at 6° 48' Virgo, we shall again subtract the discrepancy of eleven days previously.",
#   'spans': []},
#  {'text': "So he will be left with 6° 34' Virgo.", 'spans': []},
#  {'text': 'Here we will assume that some very few minutes are in error because the deduction over 12 days is too great, and the diurnal motion is not exactly the same as that obtained here from Magini.',
#   'spans': []},
#  {'text': "For consider that on April 18 preceding at 10h Mars was found at 17° 37½’ Leo, while Magini puts it at 18° 0' Leo.",
#   'spans': []},
#  {'text': 'The difference is 22½’.', 'spans': []},
#  {'text': 'Over the 33 days elapsed to May 18 this difference was diminished to the measure of 14¼’ .',
#   'spans': []},
#  {'text': 'So if we extrapolate, since over 33 days eight minutes vanished, in the same ratio, over the 12 following days 3 minutes will vanish.',
#   'spans': []},
#  {'text': 'Therefore, on May 30 the difference will be 11¼’.', 'spans': []},
#  {'text': "So, more accurately, Mars is at 6° 37' Virgo.", 'spans': []},
#  {'text': 'Similarly, on 1591 January 22 at 7h in the morning, Mars was 34° 32\' 45" from Spica with declination 17° 25\' south, at an altitude of 16° ^8.',
#   'spans': []},
#  {'text': "Therefore, after correction for horizontal variations, the declination was 17° 30'.",
#   'spans': []},
#  {'text': 'Hence, the right ascension was 230° 23\' 12", longitude 22° 33\' Scorpio, latitude 1° 0\' 30" north.',
#   'spans': []},
#  {'text': "Now this time differs from ours by 1 day 19 hours, and the diurnal motion, from Magini, is 33'.",
#   'spans': []},
#  {'text': "Therefore, 59' are required for the intervening time.",
#   'spans': []},
#  {'text': "Therefore, the remainder is the position of Mars on January 20 at 0h (which, as we said, corresponds to the other time): 21° 34' Scorpio.",
#   'spans': []},
#  {'text': 'Witness the great difference in the equations on the annual orb, despite the promise that the two anomalies of commutation would be equal.',
#   'spans': []},
#  {'text': 'The Copernican hypothesis shows us the cause.', 'spans': []},
#  {'text': "The earth at D and E was considered to be equally distant from the point of uniform motion C, but it was found to be at unequal distances, in such a way that the center of its circuit is at B towards the sun A. And by equivalence, in the Ptolemaic form the epicycle HI is not equally situated about point F, whose  eccentric path the acronychal observations have been describing to us, and about which the epicycle's motion is regular.",
#   'spans': []},
#  {'text': 'And the center of the epicycle G draws towards E, on the same side as the solar perigee.',
#   'spans': []},
#  {'text': "Similarly, in the Tychonic form the deferent KL of the planetary systems does not go around the earth C at a constant distance, although its motion is regular about this point, but the center M of its circuit draws towards the region of the sun's perigee.",
#   'spans': []},
#  {'text': 'Chapter 23', 'spans': []},
#  {'text': "From the knowledge of two distances of the sun from the earth and of the zodiacal positions and the sun’s apogee, to find the eccentricity of the sun's path (or the earth’s, for Copernicus).",
#   'spans': []},
#  {'text': 'From this it is also not difficult for us to measure the line BC tentatively.',
#   'spans': []},
#  {'text': 'Let FC be 100,000.', 'spans': []},
#  {'text': 'And because DFC is 36° 51\' and FCD is 64° 23\' 30", therefore the remaining angle FDC is 78° 45\' 27".',
#   'spans': [{'start': 12, 'end': 16, 'label': 'PARA'},
#    {'start': 31, 'end': 35, 'label': 'PARA'},
#    {'start': 81, 'end': 85, 'label': 'PARA'}]},
#  {'text': 'And as the sine of this angle is to FC (100,000), so is the sine of DFC to DC, 61,148.',
#   'spans': [{'start': 68, 'end': 72, 'label': 'PARA'}]},
#  {'text': 'In the same way, because EFC is 38° 5½’ minus a little, and FCE is 64° 23\' 30", FEC will be 77° 31\' 0" plus a little.',
#   'spans': [{'start': 25, 'end': 29, 'label': 'PARA'},
#    {'start': 60, 'end': 64, 'label': 'PARA'},
#    {'start': 80, 'end': 84, 'label': 'PARA'}]},
#  {'text': 'Therefore, EC is 63,186 minus a little.', 'spans': []},
#  {'text': "Let the earth's orb NED be set out, and on it let CBN be the line of apsides, and N perihelion, R aphelion, B the center, C the point of equality of motion, E and D the positions of the two observations, and let these be joined to C and to B. Now EC and CD are known in the same units, and angle ECD is known, viz.",
#   'spans': [{'start': 20, 'end': 24, 'label': 'PARA'},
#    {'start': 50, 'end': 54, 'label': 'PARA'},
#    {'start': 296, 'end': 300, 'label': 'PARA'}]},
#  {'text': '128° 47\' 19".', 'spans': []},
#  {'text': 'Let EC be extended, and let DO be dropped perpendicular to it from D; and also to DE let two perpendiculars CP, BQ be dropped from C and B.',
#   'spans': []},
#  {'text': 'DCO is therefore 51° 12\' 41", and CDO is 38° 47\' 19".',
#   'spans': [{'start': 0, 'end': 4, 'label': 'PARA'},
#    {'start': 34, 'end': 38, 'label': 'PARA'}]},
#  {'text': 'Therefore, where DC is 61,148,', 'spans': []},
#  {'text': 'DO will be 47,660 and CO 38,305.', 'spans': []},
#  {'text': 'And this placed on the end of CE makes EO 101,491.', 'spans': []},
#  {'text': 'But from the two given sides DO, OE about a right angle, the magnitude of DEO is obtained: 25° 9\' 20".',
#   'spans': [{'start': 74, 'end': 78, 'label': 'PARA'}]},
#  {'text': 'Therefore DE is 112,125.', 'spans': []},
#  {'text': 'The half of this, 56,062½, is the magnitude of DQ, since DB, BE are equal.',
#   'spans': []},
#  {'text': 'And because DEC was 25° 9\' 20", EDC or PDC will be 26° 3\' 21".',
#   'spans': [{'start': 12, 'end': 16, 'label': 'PARA'},
#    {'start': 32, 'end': 36, 'label': 'PARA'},
#    {'start': 39, 'end': 43, 'label': 'PARA'}]},
#  {'text': 'Therefore, where DC is 61,148, CP will come out to be 26,858 and PD is 54,932.',
#   'spans': []},
#  {'text': 'Subtract this from QD, and the remainder, PQ, is 1130½.',
#   'spans': []},
#  {'text': 'And now from the known inclination of the lines ED and NC the length CB is easily obtained.',
#   'spans': []},
#  {'text': "For since CR is the line of the aphelion, at 5° 30' Capricorn, while CD is at 17° 52' Sagittarius (because the sun is at 17° 52' Gemini), DCR will be 17° 38'.",
#   'spans': [{'start': 138, 'end': 142, 'label': 'PARA'}]},
#  {'text': 'But EDC was 26° 3\' 21".',
#   'spans': [{'start': 4, 'end': 8, 'label': 'PARA'}]},
#  {'text': 'Therefore, after subtraction, there remains the inclination of the lines in question: 8° 25\' 21".',
#   'spans': []},
#  {'text': 'From P let PS be drawn parallel to CB.', 'spans': []},
#  {'text': 'This will be equal to CB, and CP will be equal to BS.',
#   'spans': []},
#  {'text': 'So in right triangle PQS, as the whole sine  is to the tangent and secant of the angle QPS, 8° 25\' 21", so is the known magnitude of PQ to QS, 167, and SP, 1143, which is CB.',
#   'spans': [{'start': 21, 'end': 26, 'label': 'PARA'},
#    {'start': 87, 'end': 92, 'label': 'PARA'}]},
#  {'text': 'And because PC and SB are equal, with magnitude 26,858, add QS, and QB will come out to be 27,025.',
#   'spans': []},
#  {'text': 'So in the right triangle DQB, given the sides about the right angle, DB will also be given, 62,237.',
#   'spans': [{'start': 25, 'end': 30, 'label': 'PARA'}]},
#  {'text': 'Therefore, the ratio of DB to BC (the radius to the eccentricity, which is being sought) is the same as 62,237 to 1143.',
#   'spans': []},
#  {'text': 'And as 62,237 is to 100,000 so is 1143 to 1837.', 'spans': []},
#  {'text': 'This, at last, is the eccentricity sought.', 'spans': []},
#  {'text': 'It would have been less if we had accounted for the', 'spans': []},
#  {'text': 'precession of the equinoxes, for then CE would have been less.',
#   'spans': []},
#  {'text': "And so from these two observations and the accepted true position of the sun's aphelion [sic] there is provided the distance of our equalizing point C or F (which we were considering as center) from the orbit's true center B or C or M, which is 1837 where the radius of its orbit is 100,000.",
#   'spans': []},
#  {'text': "In contrast, Tycho Brahe found the sun's eccentricity, that is, the distance of the equalizing point C from the center A of the solar body (in Copernicus) or the distance of the equalizing point A of the solar motion from the cen",
#   'spans': []},
#  {'text': 'ter of the earth C (in the Tychonic-Ptolemaic supposition) to be 3584, whose half, 1792, is only slightly different from 1837.',
#   'spans': []},
#  {'text': 'It is therefore fitting that the halving of the eccentricity hold in the theory of the sun, which halving previously held for the eccentric of Mars (in Chapter 19 and 20).',
#   'spans': []},
#  {'text': "For owing to the large corrections and the use of a controverted value for the diurnal motion, the observations which I have presented are not exact enough to allow anything to be concluded from 45 parts in one hundred thousand, not to mention the ignoring of precession in Mars's and the sun's eccentric motions for the time interval involved.",
#   'spans': []},
#  {'text': 'What has been demonstrated here of the circuit of the earth can be demonstrated in exactly the same way concerning the Ptolemaic epicycle and the Tychonic deferent of the system, provided only that in the diagram the apsides be reversed.',
#   'spans': []},
#  {'text': "I have supposed here that the sun's apogee established by Tycho was in the right place, and that the orbit of the sun (or earth) which it bodily traverses is arranged in a circle.",
#   'spans': []},
#  {'text': 'Although in Ch.', 'spans': []},
#  {'text': '44 below the analogy with other planets will declare something different, the small breadth of the deflection nonetheless does not in the least vitiate our demonstration.',
#   'spans': []},
#  {'text': 'Chapter 24', 'spans': []},
#  {'text': 'A clearer proof that the epicycle or annual orb is eccentric with respect to the point of uniformity.',
#   'spans': []},
#  {'text': 'Such, then, was the beginning of this enquiry, timid and encumbered with so many concerns that the anomaly of commutation be equal on both sides.',
#   'spans': []},
#  {'text': 'Now that we have once made a hazard of this, we are buoyed by audacity  and will begin to be more free on this battlefield.',
#   'spans': []},
#  {'text': 'For I shall seek out three or more observed positions of Mars with the planet always at the same eccentric position, and from these find by trigonometry the distances of that number of points on the epicycle or annual orb from the point of uniform motion.',
#   'spans': []},
#  {'text': 'And since a circle is defined by three points, I shall use triplets of such observations to investigate the position of the circle, its apsides (previously taken as a presupposition), and its eccentricity with respect to the point of uniform motion.',
#   'spans': []},
#  {'text': 'If a fourth observation will be at hand, it will serve as a test.',
#   'spans': []},
#  {'text': 'Let the first time be 1590 March 5 at 7h 10m in the evening, since then Mars had hardly any latitude, and thus no one looking at the demonstration could be troubled by any irrelevant suspicions about the intermingling of latitude.',
#   'spans': []},
#  {'text': 'To this there correspond these moments, in which Mars returns to the same sidereal position: 1592 Jan.',
#   'spans': []},
#  {'text': '21 at 6h 41m; 1593 Dec.', 'spans': []},
#  {'text': '8 at 6h 12m; 1595 Oct.', 'spans': []},
#  {'text': '26 at 5h 44m ^1.', 'spans': []},
#  {'text': 'For the first of these times, Mars\'s [mean] longitude, according to Tycho\'s revision, is 1s 4° 38\' 50", and for subsequent times 1\' 36" greater for each.',
#   'spans': []},
#  {'text': 'For this is the motion of precession corresponding to the periodic time of one return of Mars.',
#   'spans': []},
#  {'text': 'And since Tycho places the apogee at 23½° Leo, its equation will be 11° 14\' 55", and consequently the equated anomaly in 1590 will be 1s 15° 53\' 45".',
#   'spans': []},
#  {'text': 'Now at the same time, the commutation, or difference of the mean, motions of the sun and Mars, is reckoned to be 10s 18° 19\' 56", so the equated [commutation], or the difference between the sun\'s mean motion and Mars\'s equated eccentric motion, is 10s 7° 5\' 1".',
#   'spans': []},
#  {'text': 'We shall present this first in the Copernican form, since it is simpler to perceive.',
#   'spans': []},
#  {'text': "Let α be the point of uniform motion of the earth's circuit, and let this be considered to be the circle δγ described about α, and let the sun be on the side β, such that the  line of the sun's apogee αβ lies in the direction of 5½° Cancer, even though we are going to investigate this degree freely, as if unknown, in Ch.",
#   'spans': []},
#  {'text': '25.', 'spans': []},
#  {'text': 'And let the earth be on αθ in 1590, αη in 1592, αε in 1593, and αζ in 1595.',
#   'spans': []},
#  {'text': 'And the angles θαη, ηαε, εαζ are equal, since α is the point of uniform motion and the periodic times of Mars are presupposed equal.',
#   'spans': []},
#  {'text': 'And let the planet at these four times be at κ, and its line of apsides be αλ.',
#   'spans': []},
#  {'text': 'Thus the angle θακ, according to the measure of the equated anomaly of commutation, is 127° 5\' l" ^2.',
#   'spans': []},
#  {'text': "As for the observed position of Mars, at the same time on the preceding day, the fourth,3 it was at 24° 22' Aries ^4.",
#   'spans': []},
#  {'text': "Its diurnal motion for the day would be 44'.", 'spans': []},
#  {'text': "Therefore, at our time it was seen at 25° 6' Aries, which is the position of the line θκ.",
#   'spans': []},
#  {'text': 'But ακ is directed towards 15° 53\' 45" Taurus.', 'spans': []},
#  {'text': 'Therefore, θκα is 20° 47\' 45".', 'spans': []},
#  {'text': 'So the remainder αθκ to make up two right angles is 32° 7\' 14".',
#   'spans': []},
#  {'text': 'Now as the sine of αθκ is to ακ, which we shall say is 100,000 units, so is [the sine of] θκα to θα, which is what is sought.',
#   'spans': []},
#  {'text': 'Therefore, θα is 66,774.', 'spans': []},
#  {'text': 'Now if the remaining lines ηα, εα, ζα, will turn out to be of the same length, my suspicion will be false, but if they are different, my triumph will be complete.',
#   'spans': []},
#  {'text': 'Second, then, in 1592 at our moment the equated longitude was 1s 15° 55\' 23"; the equated commutation was 8s 24° 10\' 34" — that is, the angle ηακ is 84° 10\' 34".',
#   'spans': []},
#  {'text': 'It was observed on January 23 at 7h 15m at 11° 34½’ Aries, with the correction for parallax ^5.',
#   'spans': []},
#  {'text': "And its motion over two days was 1° 25'.", 'spans': []},
#  {'text': 'Therefore on the 21st at 7h 15m it was seen at 10° 9½’ Aries.',
#   'spans': []},
#  {'text': 'Let the remaining parts of an hour deduct the half minute.',
#   'spans': []},
#  {'text': 'Therefore, the angle ηκα is 35° 46\' 23", and αηκ is 60° 3\' 3", and αη is 67,467, now  longer than αθ.',
#   'spans': []},
#  {'text': 'This is doubtless because the sun has descended towards perigee, and the earth has been moved from θ to η; thus, in this region the sun is found beyond β at a nearer point.',
#   'spans': []},
#  {'text': 'Third, in 1593 at our moment the equated longitude was 1s 15° 56\' 56", the equated commutation was 7s 11° 16\' 16", which makes εακ 41° 16\' 16".',
#   'spans': []},
#  {'text': "It was observed December 10 at 7h 20m at 4° 45' Aries, parallax corrected ^6.",
#   'spans': []},
#  {'text': "Its motion over two days was 1° 8'.", 'spans': []},
#  {'text': 'Therefore, on December 8 at 7h 20m it was seen at 3° 37’ Aries, while at our time of 6h 12m it was at 3° 35½’ Aries.',
#   'spans': []},
#  {'text': 'Hence, εκα is 42° 21’ 30" and κεα is 96° 22’ 14", and αε is 67,794, again longer, for it is yet closer to the sun\'s perigee.',
#   'spans': []},
#  {'text': 'Fourth, in 1595 at our moment the equated longitude was 1s 15° 58\' 30" and the [equated] commutation was 5s 28° 21\' 55", which makes the angle καζ 1° 38\' 5".',
#   'spans': []},
#  {'text': 'It was observed on October 27 at 12h 20m at 18° 52’ 15" Taurus, retrograde ^7.',
#   'spans': []},
#  {'text': "Its diurnal motion was 23'.", 'spans': []},
#  {'text': 'And so on the 26th at 12h 20m it was at 19° 15\' 15" Taurus, while at our time it was at 19° 21’ 35" Taurus.',
#   'spans': []},
#  {'text': 'Therefore, ακζ is 3° 23’ 5", and the supplement of αζκ is 5° l’ 10", and αζ is 67,478.',
#   'spans': []},
#  {'text': 'But this last operation is untrustworthy, owing to the small angles of the triangle.',
#   'spans': []},
#  {'text': "For if an error of one or two minutes is made either in observing or in computing Mars's eccentric position using Tycho's hypothesis, the ratio of the angles is easily changed perceptibly.",
#   'spans': []},
#  {'text': 'But for now I shall present all four lines for inspection.',
#   'spans': []},
#  {'text': "So the longest is αε, which is also the closest to the sun's perigee; the shortest is αθ, which is also the farthest from the sun's perigee; and αζ and αη are about equal, because they are also nearly equally removed from perigee.",
#   'spans': []},
#  {'text': 'Moreover, even if αζ is a little longer than αη which is nearer the perigee, this should be attributed to the smallness of the angles at ζ, through which such a small error as this could easily be introduced.',
#   'spans': []},
#  {'text': "Therefore, the circle δγ which Copernicus described about the point x of uniformity of the earth's motion, is not the earth's path.",
#   'spans': []},
#  {'text': 'There is instead some other circle θηεζ on which the earth is found, whose center lies in the same direction as the sun—that is, at β.',
#   'spans': []},
#  {'text': "In the Ptolemaic form, let the earth be at A, the sun's sphere be ΞΟΙΤ, Κ the putative center of the epicycle; that is, the center about which [is described] the epicycle ΔΓ, itself putative, which is equal to the [circle of the] theory of the sun.",
#   'spans': []},
#  {'text': "The total equivalence between the hypotheses of Copernicus and Brahe requires this to be done, although for the present demonstration it doesn't matter what",
#   'spans': []},
#  {'text': "ratio the sun's orb and the planet's epicycle have, provided that they have equal periods.",
#   'spans': []},
#  {'text': "And let ΑΛ be Mars's line of apsides.", 'spans': []},
#  {'text': 'Let ΑΚ, ΑΛ be parallel to ακ, αλ in the preceding Copernican form.',
#   'spans': []},
#  {'text': "From the center of the earth Α, let the lines ΑΘ, ΑΗ, ΑΕ, ΑΖ be drawn parallel to the previous lines κθ, κη, κε, κζ, and equal to them, so that Mars is at Θ in 1590, at Η in 1592, at Ε in 1593, and at Ζ in 1595; and at the same time the sun's mean position at those times is ΑΤ, ΑΙ, ΑΟ, ΑΧ, respectively, so that ΚΘ and ΑΤ are parallel (as is known from the Ptolemaic hypothesis), and so",
#   'spans': []},
#  {'text': 'on for the rest.', 'spans': []},
#  {'text': "With Θ, Η, Ε, and Ζ connected with Κ, it will be demonstrated as before, with exactly the same numbers, lines, and angles, that these lines are unequal, contrary to common opinion, and consequently that Mars does not traverse the circle ΓΔ, whose center is at the center of uniform motion Κ, but the circle ΖΗΕΘ instead, whose center lies in the direction of Β from Κ, very near to the line ΚΒ, which should be parallel to the line drawn from the earth Α through the sun's perigee.",
#   'spans': []},
#  {'text': "Therefore, the epicycle's apogee lies in the direction of the sun's perigee.",
#   'spans': []},
#  {'text': "And because the epicycle, owing to the total equivalence just mentioned, is to be supposed equal to the sun's circuit, with ΖΚ parallel to ΧΑ, ΕΚ to ΟΑ, ΗΚ to ΙΑ, and ΘΚ to ΤΑ, it is also likely that ΧΑ, ΟΑ, ΙΑ, and ΤΑ are unequal, and that the point of the sun's mean position (the center of the sun's epicycle, in the Brahean conception) does not stand at the same distance from the point of uniform motion throughout its circuit.",
#   'spans': []},
#  {'text': 'This I remark only in passing: it has no effect upon the present demonstration, but serves as an extension to it.',
#   'spans': []},
#  {'text': "In the Tychonic form, let A be the earth, and about it let the sun's concentric CD be described, and let this be considered to be the deferent of the system of the planets, since A is the point of uniform motion of the sun's concentric.",
#   'spans': []},
#  {'text': 'Therefore the sun itself will be on another eccentric circle.',
#   'spans': []},
#  {'text': "Let its center be in the direction of B from A. Now let AL be the reference for Mars's line of apsides, so that the line of apsides, in the circling and translating of its eccentric, remains ever parallel to AL.",
#   'spans': []},
#  {'text': "And let the lines of the sun's mean motion at our four moments be AH, AT, AE, AS, and from A let the lines along which Mars is observed be extended in the direction of one or another degree of the zodiac in accordance with the description above.",
#   'spans': []},
#  {'text': 'And since at all four', 'spans': []},
#  {'text': "times Mars is supposed to be at the same place on the eccentric, its distances from the points of the sun's mean position will all be equal and parallel.",
#   'spans': []},
#  {'text': 'Let them be GH, FT, IE, and KS, all equal, and let the angles LHG, LTF, LEI, LSK, all be equal to the previous angle ΛΑΚ or λακ, so that at our moments Mars might be at G, F, I, K. I would note in passing that these four points G, F, I, K, in actual fact will make an arc exactly equal in length and placement to the previous arc ΘΗΕΖ in the Ptolemaic form.',
#   'spans': [{'start': 62, 'end': 67, 'label': 'PARA'},
#    {'start': 67, 'end': 72, 'label': 'PARA'},
#    {'start': 72, 'end': 77, 'label': 'PARA'},
#    {'start': 77, 'end': 82, 'label': 'PARA'}]},
# ...
#   'spans': []},
#  {'text': 'That is, that the earth proceeds nonuniformly on its orbit, slowing when it recedes far from the sun and speeding up when it approaches.',
#   'spans': []},
#  {'text': 'This is in conformity with physical principles and with the analogy with other planets.',
#   'spans': []},
#  {'text': "In the same way it has been demonstrated in the Ptolemaic form that the epicycle is eccentric with respect to the point about which its motion is uniform, and that its eccentricity is half of the sun's eccentricity as it is commonly determined, and in the opposite direction.",
#   'spans': []},
#  {'text': "Finally, in the Tychonic form it has been demonstrated that the point whence originate the planets' eccentricities does not move on the sun's concentric, but throughout its course is unequally distant from the earth, about which it moves regularly and uniformly; and that it is farther away near the sun's perigee, and nearer at apogee, again by half of the sun's eccentricity.",
#   'spans': []},
#  {'text': "And so, since this Ptolemaic epicycle and this Brahean deferent have so great an analogy with the theory of the sun, it is likely that they also have a greater analogy: that is, the sun's true eccentricity, too, will only be half of that computed from the maximum equation; or, what is the same thing, the sun will make use of an equant, whose eccentricity is twice the eccentric's eccentricity.",
#   'spans': []},
#  {'text': "I admit that this line of argument is a little weaker when applied to the Ptolemaic and Tychonic form, insofar as we are using the sun's mean motion, following the authorities.",
#   'spans': []},
#  {'text': "The argument consequently will become clearer when, moved by those reasons adduced in Chapter 6 above, I measure out the planet's motion by the sun's apparent motion.",
#   'spans': []},
#  {'text': 'Chapter 26', 'spans': []},
#  {'text': "demonstration from the same observations that the epicycle is eccentric with respect to the point of attachment or axis, and that the annual orb (and so also the earth's path around the sun, or the sun's around the earth) is eccentric with respect to the body of the sun or earth, with an eccentricity just half that which Tycho Brahe found through equations of the sun's motion.",
#   'spans': []},
#  {'text': 'We shall now go through the observations1 again, carefully: On 1590 March 4 at 7h 10m, Mars was found by careful observation and calculation to be at 24° 22\' 56" Aries with latitude 0° 3\' 20" S. At that time, 8° Aries was setting, so Mars was rather low.',
#   'spans': []},
#  {'text': "Therefore, it was raised up towards the east by refraction, so it seems right that without refraction it would have been seen at 24° 20' Aries.",
#   'spans': []},
#  {'text': 'Its parallax can only be very small, particularly at this distance, for Mars was near the sun and therefore had receded very far from the center of the earth.',
#   'spans': []},
#  {'text': 'On 1592 January 23 at 7h 20m, using only one stellar distance from Mars, without the confirmation of another, Mars was found at 11° 32\' 44" Aries with latitude 0° 1\' 36" S. And so we shall make no changes for horizontal variations, although we suspect an uncertainty of one or two minutes.',
#   'spans': []},
#  {'text': 'On 1593 December 7 at 8h 0m Mars was found at 3° 6\' 50" Aries with no danger of horizontal variation, with latitude 7’ 9" S. However, the right ascension found using three stars showed a discrepancy of 4\', and the value taken as true was the mean between the extremes.',
#   'spans': []},
#  {'text': 'On 1595 October 25 at 8h 10m, the planet\'s distance from three fixed stars was observed, and by unanimous consensus the planet was found to be at 19° 39\' 25" [Taurus] with latitude 0° 12\' 41" S.',
#   'spans': []},
#  {'text': 'Now we shall reduce the three subsequent times to the first.',
#   'spans': []},
#  {'text': 'Accordingly, to its sidereal position', 'spans': []},
#  {'text': 'The motion over three days and 35 minutes of time in 1592 was 2° 9\' 4", according to Magini ^2.',
#   'spans': []},
#  {'text': 'Therefore, at our time Mars was seen at 9° 23\' 40" [Aries].',
#   'spans': []},
#  {'text': 'In 1593 the motion over 1 hour 45 min., from the diurnal motion of 33\', is 2\' 25".',
#   'spans': []},
#  {'text': 'And so at our time Mars\'s position comes out to be 3° 4\' 27" Aries.',
#   'spans': []},
#  {'text': 'Likewise, in 1595 the motion over 2 hours 25 min., from a diurnal motion of 22\' 11", is 2\' 14".',
#   'spans': []},
#  {'text': 'Therefore at our time the position of Mars comes out to be 19° 41\' 39" Taurus.',
#   'spans': []},
#  {'text': 'FROM THIS THERE FOLLOWS THE TABLE OF POSITIONS',
#   'spans': [{'start': 0, 'end': 4, 'label': 'PARA'},
#    {'start': 5, 'end': 9, 'label': 'PARA'},
#    {'start': 10, 'end': 14, 'label': 'PARA'},
#    {'start': 16, 'end': 20, 'label': 'PARA'},
#    {'start': 20, 'end': 24, 'label': 'PARA'},
#    {'start': 24, 'end': 28, 'label': 'PARA'},
#    {'start': 28, 'end': 32, 'label': 'PARA'},
#    {'start': 37, 'end': 41, 'label': 'PARA'},
#    {'start': 41, 'end': 45, 'label': 'PARA'}]},
#  {'text': 'Now because we have proposed to enquire how far the earth is from the center of the sun, we will need first of all to use the hypothesis constructed above in Ch.',
#   'spans': []},
#  {'text': "16, from oppositions to the sun's apparent position, to find the position of the line drawn from the center of the sun through the body of Mars to the zodiac.",
#   'spans': []},
#  {'text': 'And on 1595 October 25 at 5h 45m that line is found at 14° 19\' 52" Taurus.',
#   'spans': []},
#  {'text': 'Therefore, for the three other times it is set back each time by 1\' 36".',
#   'spans': []},
#  {'text': 'Thus, in 1593 it was at 14° 18\' 16" Taurus; in 1592, at 14° 16\' 40" Taurus; and in 1590, at 14° 15\' 4" Taurus.',
#   'spans': []},
#  {'text': 'Let the First Diagram be in Copernicus’s Form', 'spans': []},
#  {'text': "And let α be the center of the sun; β the center of Mars's eccentric, drawn through ο; χ the center of uniform motion for Mars's eccentric; γ the center of the earth's eccentric; δ, ε, ζ, η four positions of the earth, opposite the sun's apparent positions; θ the position of Mars on its eccentric.",
#   'spans': []},
#  {'text': 'Let all points be connected with one another.', 'spans': []},
#  {'text': '3', 'spans': []},
#  {'text': 'We shall now test the magnitude of the eccentricity that may be deduced from these distances.',
#   'spans': []},
#  {'text': "If the sun's theory lacks an equant, the eccentricity of its circle will turn out to be about 3600.",
#   'spans': []},
#  {'text': 'This is because we used the true or apparent positions of the sun, whose point of uniform motion has to be that far (namely, 3600) from the center of the world, as Brahe has proved from solar observations.',
#   'spans': []},
#  {'text': "But if, on the other hand, the eccentricity turns out to be less, and is about half the Brahean value, we have won, and vindicated our contention, that the point of uniform motion found by Brahe is not the center of the sun's eccentric.",
#   'spans': []},
#  {'text': "You can see at a glance (I would note in passing) that αζ is the shortest, it being near the sun's perigee; next, that αε is longer, it being in Aquarius, 34 degrees from perigee; then αη, it being 54 degrees from perigee; and lastly, that αδ is longest, because it is 80 degrees from perigee.",
#   'spans': []},
#  {'text': 'And since αζ is almost at perigee, it will be hardly any longer than the shortest.',
#   'spans': []},
#  {'text': 'Similarly, since αδ is near the middle elongation, it will be only a little less than the mean distance.',
#   'spans': []},
#  {'text': 'Therefore, the eccentricity will come out to be a little greater than 1038, which is the difference between δα and ζα.',
#   'spans': []},
#  {'text': 'And if δα is assigned the measure of 100,000, 1038 will have the value 1539; and this is about what the eccentricity will amount to (it is actually a little greater).',
#   'spans': []},
#  {'text': 'And this is much closer to 1800, half the Tychonic value, than to the full value of 3600.',
#   'spans': []},
#  {'text': "The same is to be said of the sun's apogee.", 'spans': []},
#  {'text': "For because ζα is shortest, the perigee is about 25° 53' Sagittarius.",
#   'spans': []},
#  {'text': "And because εα is shorter than ηα, the perigee is closer to 10° 17' Aquarius than to 11° 42' Scorpio.",
#   'spans': []},
#  {'text': "But the mean is 25° 57' Sagittarius.", 'spans': []},
#  {'text': "Therefore, the perigee is beyond 25° 57' Sagittarius and before 10° 17' Aquarius; that is, in Capricorn.",
#   'spans': []},
#  {'text': 'This I wanted to give as a foretaste to make up for the coming labors.',
#   'spans': []},
#  {'text': 'For now I shall follow the geometric path to investigate the position of the apogee and the eccentricity.',
#   'spans': []},
#  {'text': 'And since three points determine a circle, I shall at first use the points δ, ζ, and η.\nI proceed as in Ch.',
#   'spans': []},
#  {'text': '25 above.', 'spans': []},
#  {'text': 'Since the points δ, ζ, η are placed on a single circumference with center γ, the angle δηζ will be half of the angle δγζ, and its measure will be the arc δζ.',
#   'spans': []},
#  {'text': 'Therefore, the ratio of δζ to the radius δγ, and to the eccentricity γα, will be given, together with the angle δαγ, because αγ lies in the direction of the apsides.',
#   'spans': []},
#  {'text': 'But for the knowledge of the angle δηζ and of the line δζ, we need to solve the three triangles.',
#   'spans': []},
#  {'text': '4', 'spans': []},
#  {'text': 'And yet it was said before that using δ and ζ the eccentricity comes out to be a little greater than 1539, supposing that ζ is nearest to perigee.',
#   'spans': []},
#  {'text': 'But since here (letting η be received into the company in place of ζ) the eccentricity comes out much greater, this hints, although erroneously, that there is some line at perigee which is still shorter than αζ.',
#   'spans': []},
#  {'text': 'In order that this distance at perigee might be able to be shorter than αζ, this line of argument has moved the perigee to 16 Capricorn, that is, farther from αζ.',
#   'spans': []},
#  {'text': "But since we already know that the sun's perigee is not in 16 Capricorn but in 6 Capricorn, it is appropriate to assign the cause of the slight error to the point η and to the excessive length of the line αη ^5.",
#   'spans': []},
#  {'text': 'For the result of this is that the circle δεη would be too large, and its radius δγ too long; and consequently γα would be too long, and γ would move perpendicularly away from the line δη, but obliquely from the point ζ. Thus, the line γα would now be placed too far to the east.',
#   'spans': []},
#  {'text': 'Therefore, letting δ and γ remain, let αη be supposed shorter.',
#   'spans': []},
#  {'text': 'Then the center γ moves perpendicularly toward the line δη, and δγ thus becomes shorter.',
#   'spans': []},
#  {'text': 'And because γ approaches δη perpendicularly, it recedes obliquely from the present γα.',
#   'spans': []},
#  {'text': 'Hence, if a straight line be drawn from α through the new position of γ, it will be inclined back towards δ.',
#   'spans': []},
#  {'text': 'You thus see how shortening αη helps us in two ways.', 'spans': []},
#  {'text': 'But to shorten αη is a very easy, small change, because the angles are small: it can be done by saying that the planet was seen in a slightly prior position along a line drawn from η below θ.',
#   'spans': []},
#  {'text': '6 For example, let the observed position of Mars be 19° 40\' Taurus, and the supplement αηθ be 7° 58\' 26", and ηθα 5° 20\' 8": then αη will be 67,030.',
#   'spans': []},
#  {'text': 'The second and third triangles are then changed, αηδ becoming 23° 53\' 0", and αηζ 67° 15\' 32".',
#   'spans': []},
#  {'text': 'Therefore, δηζ is 43° 22\' 26", and δγζ 86° 44\' 52".',
#   'spans': []},
#  {'text': 'The remaining  angles are 93° 15\' 8", whose half, γδζ, is 46° 37\' 34", and γδα is 1° 10\' 12".',
#   'spans': []},
#  {'text': 'Hence δγ is 67,892.', 'spans': []},
#  {'text': 'And where this is 100000, αδ will be 99,416, and δγα 73° 24\' 39".',
#   'spans': []},
#  {'text': "Consequently the perigee is in 10° 36' Capricorn, and the eccentricity is still about 2100.",
#   'spans': []},
#  {'text': 'Thus, as the true perigee was approached the eccentricity decreased, and so when we get exactly to the correct perigee we shall also get exactly to the halving of the eccentricity.',
#   'spans': []},
#  {'text': 'But it is nonetheless worthwhile to find out, in addition, how much we gain by changing the line αθ, adding one minute to the computed eccentric position of Mars while keeping fixed the point of observation (that is, the point η) for the year 1595.',
#   'spans': []},
#  {'text': 'With αθ accordingly moved forward, if these lines of sight ηθ, ζθ, and the rest were to stay the same, it would come about that αθ would be intersected by ηθ at a place higher than θ; and on the other hand it would be intersected by ζθ and its counterparts at a place lower than θ.',
#   'spans': []},
#  {'text': '7 So αθ would not keep the same length.', 'spans': []},
#  {'text': 'But since we are supposing that Mars is at the same eccentric position all four times, the length of αθ will also be the same for all four times.',
#   'spans': []},
#  {'text': 'Therefore, in order that the point of intersection θ be the same, and nonetheless the lines of sight go towards their original zodiacal positions, it will be necessary to draw a line parallel to ηθ somewhat lower, thus making αη shorter; and also a line outside ζθ and parallel to it, by which αζ would be lengthened; and so on for the rest.',
#   'spans': []},
#  {'text': 'Next, the whole labor is to be repeated from the beginning.',
#   'spans': []},
#  {'text': 'For δεθα will now be 19° 56\' 4", εθα 34° 53\' 40", ζθα 41° 14\' 46", and ηθα 5° 21\' 8".',
#   'spans': []},
#  {'text': 'Therefore δα will be 67,522, εα 66,660, ζα 66,451, ηα 66,963.',
#   'spans': []},
#  {'text': 'Hence, αδζ will be 45° 26\' 37", αηδ 23° 54\' 30", αηζ 67° 20\' 48".',
#   'spans': []},
#  {'text': 'And δηζ will be 43° 26\' 18", and δγζ 86° 52\' 36", γδζ 46° 33\' 42", and γδα 1° 7\' 5"- a different angle from different beginnings.',
#   'spans': []},
#  {'text': 'Now, when αζ is divided by the sine αδζ, and the quotient multiplied by the sine of δαζ, the product is δζ, 93,252.',
#   'spans': []},
#  {'text': 'Again, when this is divided into the sine of δγζ, and the quotient is multiplied by the sine of δζγ, the product will be δγ, 67,823.',
#   'spans': []},
#  {'text': 'Hence the angle δγα is 76° 37’ 30", and the perigee is at 7° 23\' Capricorn, with an eccentricity about 1880, which would clearly be 1800 if the perigee were brought back to 5½ Capricorn, as could happen through the combined effect of both causes.',
#   'spans': []},
#  {'text': 'For if you now subtract only half a minute from the apparent position for 1595, we will be within range.',
#   'spans': []},
#  {'text': 'And there could easily be a one minute error in the equations of the eccentric found by the hypothesis of Chapter 16.',
#   'spans': []},
#  {'text': 'So, since the result is easily vitiated by the data from 1595, let us now omit them and use the remaining three points δ, ε, ζ, keeping the most recent correction of eccentric position, and forming the new triangles δαε and εαζ.',
#   'spans': []},
#  {'text': '8', 'spans': []},
#  {'text': 'And because δζ remains 93,252, as before, dividing the sine of γδζ by the sine of δγζ and multiplying the quotient by δζ gives γδ as 67,873.',
#   'spans': []},
#  {'text': 'But αδ is 67,522.', 'spans': []},
#  {'text': 'From this and γδ, δγα is found to be 75° 8\' 40" and the perigee in 8 51 45 Capricorn, about what it was before.',
#   'spans': []},
#  {'text': 'The eccentricity, somewhat more than 2000, is to be decreased to 1800 (as before), if the perigee were to be moved back to 5½° Capricorn.',
#   'spans': []}]

# %%
text= "On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15."  #try to find the Misaligned Tokens
text[22:28]
# Out:
# '8h 20m'
