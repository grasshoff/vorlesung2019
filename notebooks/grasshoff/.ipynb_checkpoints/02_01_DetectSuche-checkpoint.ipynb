# %% [markdown]
# # Vorlesung 4: Algorithmische Wissenschaftstheorie, Gerd Graßhoff
# ## Epistemische Ausdrücke
# Ziele und Funde

# %% [markdown]
# # Vorbereitung

# %%
# Loading packages
import pandas as pd
import re
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %%
# loading Nasa abstracts
dfExoplanetsNASA = pd.read_json('./data/dfExoplanetsNASA_v2.json', orient = 'table')
dfExoplanetsNASA = dfExoplanetsNASA[dfExoplanetsNASA.abstract != 'None'].reset_index(drop=True)

# %% [markdown]
# # Analyse

# %%
len(dfExoplanetsNASA)
# Out:
# 29745

# %%
dfExoplanetsNASA.head()
# Out:
#                bibcode                           DOI  \
# 0  2019NewA...70....1B  10.1016/j.newast.2018.12.005
# 1  2019CNSNS..71...82A   10.1016/j.cnsns.2018.10.026
# 2  2019NewA...69...27E  10.1016/j.newast.2018.11.008
# 3  2019MNRAS.483.3465F         10.1093/mnras/sty3367
# 4  2019MNRAS.483.3448M         10.1093/mnras/sty3346
#
#                                              authors  \
# 0  [Zhang Bin, Qian Sheng-Bang, Liu Nian-Ping, Zh...
# 1  [M. Alvarez-Ramírez, E. Barrabés, M. Medina, M...
# 2                        [Şeyda Enez, Hasan Ali Dal]
# 3                                 [Giacomo Fragione]
# 4  [Kristina Monsch, Barbara Ercolano, Giovanni P...
#
#                                          affiliation  \
# 0  [School of Physics and Electronic Science, Gui...
# 1  [Dept. de Matemáticas, UAM-Iztapalapa, Ciudad ...
# 2  [Ege University, Department of Astronomy and S...
# 3  [Racah Institute for Physics, The Hebrew Unive...
# 4  [Universitäts-Sternwarte, Ludwig-Maximilians-U...
#
#                                     acknowledgements grant   published  year  \
# 0  We thank the anonymous referee for useful comm...    []  2019-07-00  2019
# 1  E. Barrabs has been supported by grants MTM201...    []  2019-06-00  2019
# 2  We wish to thank the Turkish Scientific and Te...    []  2019-05-00  2019
# 3  Author thanks Nader Haghighipour for useful an...    []  2019-03-00  2019
# 4  We thank Giovanni Rosotti and Jeff Jennings fo...    []  2019-03-00  2019
#
#                                                title  \
# 0  First photometric study of a short-period deta...
# 1  Ejection-Collision orbits in the symmetric col...
# 2  Cool spot migration and flare activity of KIC ...
# 3  Dynamical origin of S-type planets in close bi...
# 4  The imprint of X-ray photoevaporation of plane...
#
#                                             abstract  \
# 0  NSVS 10441882 is a newly discovered eclipsing ...
# 1  In this paper, we consider the collinear symme...
# 2  Analysing the photometrical data taken from th...
# 3  Understanding the origin of planets that have ...
# 4  High-energy radiation from a planet host star ...
#
#                                             keywords  citation_count
# 0  [Binary, Eclipsing binary, Light curve, Orbita...               0
# 1  [Collinear four-body problem, Ejection/collisi...               0
# 2  [Techniques: Photometric, Methods: Statistical...               0
# 3  [planets and satellites: general, binaries: cl...               0
# 4  [planets and satellites: formation, planet-dis...               0

# %% [markdown]
# ## Select columns

# %%
dfExoplanets = dfExoplanetsNASA[['title', 'year', 'abstract']]

# %%
dfExoplanets.head()
# Out:
#                                                title  year  \
# 0  First photometric study of a short-period deta...  2019
# 1  Ejection-Collision orbits in the symmetric col...  2019
# 2  Cool spot migration and flare activity of KIC ...  2019
# 3  Dynamical origin of S-type planets in close bi...  2019
# 4  The imprint of X-ray photoevaporation of plane...  2019
#
#                                             abstract
# 0  NSVS 10441882 is a newly discovered eclipsing ...
# 1  In this paper, we consider the collinear symme...
# 2  Analysing the photometrical data taken from th...
# 3  Understanding the origin of planets that have ...
# 4  High-energy radiation from a planet host star ...

# %% [markdown]
# # Select items

# %%
dfExoplanets.iloc[2]
# Out:
# title       Cool spot migration and flare activity of KIC ...
# year                                                     2019
# abstract    Analysing the photometrical data taken from th...
# Name: 2, dtype: object

# %%
dfExoplanets['abstract'].iloc[2]
# Out:
# 'Analysing the photometrical data taken from the Kepler Mission Database, the results obtained from both the One Phase Exponential Association model derived for the flare activity and the spot migration on the surface of eclipsing binary system KIC 11560447 are presented. A sinusoidal variation due to the rotation modulation is defined. There are two cool spots separated by about 100° longitudinally. It is seen that the parameters of these spotted areas such as radii, latitudes and longitudes, were varying during observing seasons. Apart from the cool spots, flare activity is also detected on the target, and 226 flares were determined with their parameters. Modelling the distribution of flare equivalent durations versus the flare total times, the Plateau parameter was found to be 1.4114 ± 0.1712 s in the logarithmic scale, while the Half-time value was found to be 2394.03 s. The frequency of flare N<SUB>1</SUB>, which is the number of flares per an hour in the system, was computed as 0.064454 h<SUP>-1</SUP> , while the flare-equivalent duration emitting per an hour, N<SUB>2</SUB> frequency, was found to be 0.000058.'

# %% [markdown]
# # Search for expressions

# %%
suchwort="know"
filtAbst=dfExoplanets['abstract'].str.contains(suchwort)
dfS=dfExoplanets[filtAbst]
len(dfS)
# Out:
# 5833

# %%
def filt(S):
    doesC=dfExoplanets['abstract'].str.contains(S)
    return(doesC)

# %%
dfS=dfExoplanets[filt(suchwort)]
len(dfS)
# Out:
# 10483

# %%
c1=Counter(dfExoplanets["abstract"].str.contains(suchwort))
c1
# Out:
# Counter({False: 19262, True: 10483})

# %%
dfExoplanets["count"]=dfExoplanets["abstract"].str.count(suchwort,re.I)

# %%
dfExoplanets.sort_values(by=["count"],ascending=False)
# Out:
#                                                    title  year  \
# 9035                              AAS 228: Day 3 morning  2016
# 11600  Robust high-contrast companion detection from ...  2015
# 5585   Detector with internal gain for short-wave inf...  2017
# 7310   Development of an Ultra-Stable Mid-Infrared De...  2017
# 28254     Two Extremely Hot Exoplanets Caught in Transit  2004
# 15606  Searching for transits in the WTS with the dif...  2013
# 29292                    Exoplanets: The Hunt Continues!  2001
# 2139   Development of transition edge sensor detector...  2018
# 27005                          Optica aperture synthesis  2006
# 13226  Extrasolar planets detections and statistics t...  2014
# 7326   Superconducting Nanowire Single-Photon Detecto...  2017
# 15552  Sub-pixel calibration for Weak Lensing and Ast...  2014
# 12783  Ultra-Low-Noise Sub-mm/Far-IR Detectors for Sp...  2015
# 13897  A near-infrared SETI experiment: probability d...  2014
# 19403  Detection of Potential Transit Signals in the ...  2012
# 12122  Detecting stars, galaxies, and asteroids with ...  2015
# 29430                                 Exoplanets Galore!  2000
# 16797  Spectral features of Earth-like planets and th...  2013
# 366    An Ultra-Stable Mid-Infrared Detector for the ...  2019
# 27658  Comparative blind test of five planetary trans...  2005
# 17642  Radio observations of the brown dwarf- exoplan...  2013
# 59     On the robustness of analysis techniques for m...  2019
# 15798  Planets around stars in young nearby associati...  2013
# 25080  Detecting transits from Earth-sized planets ar...  2008
# 2428            Snowballs in Euclid and WFIRST detectors  2018
# 7632   Radial Velocity Fiber-Fed Spectrographs Toward...  2016
# 29120            Eddington's planet finding capabilities  2002
# 8920   Detector control and data acquisition for the ...  2016
# 2202      Searching for Exoplanets Around X-Ray Binaries  2018
# 16110  Intensity information extraction in Geiger mod...  2013
# ...                                                  ...   ...
# 11753      The Gaia Mission, Binary Stars and Exoplanets  2015
# 11752  The Gemini NICI Planet-Finding Campaign: asymm...  2015
# 11751  The Age and Age Spread of the Praesepe and Hya...  2015
# 11750     Solar-type activity: Epochs of cycle formation  2015
# 11749  Quantum and post-Newtonian effects in the anom...  2015
# 11748               Zdeněk Kopal: Astronomer and Teacher  2015
# 11772          True Masses of Radial-Velocity Exoplanets  2015
# 11777  ExoMol molecular line lists - IX. The spectrum...  2015
# 11807  How Rocky Are They? The Composition Distributi...  2015
# 11779                  The formation of the solar system  2015
# 11806     Did gamma ray burst induce Cambrian explosion?  2015
# 11805  Close encounters involving free-floating plane...  2015
# 11804  3D climate modeling of Earth-like extrasolar p...  2015
# 11803         Fast Direct Methods for Gaussian Processes  2015
# 11802  Analysis of deletion breakpoints from 1,092 hu...  2015
# 11801  Detecting Differential Rotation and Starspot E...  2015
# 11800  The Interaction of Venus-like, M-dwarf Planets...  2015
# 11797  Lifetime and Spectral Evolution of a Magma Oce...  2015
# 11796  Stability of CO2 Atmospheres on Desiccated M D...  2015
# 11795  Limb darkening and exoplanets: testing stellar...  2015
# 11794  Photonic spatial reformatting of stellar light...  2015
# 11793                                   Mass of WASP-33b  2015
# 11791  Consolidating and Crushing Exoplanets: Did It ...  2015
# 11789  Reconstructing the star formation history of t...  2015
# 11787  Power-law tails in probability density functio...  2015
# 11786  On the Atmospheric Extinction Reduction Proced...  2015
# 11784                     What is the Mass of α Cen B b?  2015
# 11783  A giant comet-like cloud of hydrogen escaping ...  2015
# 11780  Miscibility Calculations for Water and Hydroge...  2015
# 29744  The Importance of Methane to Pressure-Induced ...  1971
#
#                                                 abstract  count
# 9035   Editors Note:This week were at the 228th AAS M...     18
# 11600  Context. Long-baseline interferometry is an im...     15
# 5585   &lt;title&gt;Abstarct.Highly sensitive photon ...     14
# 7310   The discovery of the Trappist-1 system, which ...     13
# 28254  VLT Measures Properties of New Jupiter-Size Ob...     12
# 15606  The search for exo-planets is currently one of...     12
# 29292  Swiss Telescope at La Silla Very Successful Su...     12
# 2139   The search for biosignatures in the atmosphere...     12
# 27005  Optical long baseline stellar interferometry i...     12
# 13226  Gravitational microlensing was proposed thirty...     12
# 7326   Superconducting nanowire single-photon detecto...     11
# 15552  We have recently developed and demonstrated a ...     11
# 12783  The sub-mm and Far-IR spectrum is rich with in...     11
# 13897  A Search for Extraterrestrial Life (SETI), bas...     11
# 19403  We present the results of a search for potenti...     11
# 12122  Context. Gaia is Europe's space astrometry mis...     11
# 29430  Eight New Very Low-Mass Companions to Solar-Ty...     11
# 16797  Context. In recent years, more and more transi...     11
# 366    Future space missions such as Origins Space Te...     10
# 27658  Because photometric surveys of exoplanet trans...     10
# 17642  Although exoplanets and brown dwarfs have been...     10
# 59     High-resolution Doppler spectroscopy provides ...     10
# 15798  Context. Stars in young nearby associations ar...     10
# 25080  Context: Detecting regular dips in the light c...     10
# 2428   Snowballs are transient events observed in HgC...     10
# 7632   This thesis is developed in the framework of t...     10
# 29120  The capabilities of Eddington for the detectio...      9
# 8920   The Wide-Field Infrared Survey Telescope (WFIR...      9
# 2202   Finding planets around ordinary stars is great...      9
# 16110  Geiger-mode detectors have single photon sensi...      9
# ...                                                  ...    ...
# 11753  On the 19th of December 2013, the Gaia spacecr...      0
# 11752  We report here the highest resolution near-IR ...      0
# 11751  We fit the upper main sequence of the Praesepe...      0
# 11750  The diagram of indices of coronal and chromosp...      0
# 11749  We study the motion of a secondary celestial b...      0
# 11748  Though the title points to a wider program tha...      0
# 11772  We study the task of estimating the true masse...      0
# 11777  Accurate line lists are calculated for alumini...      0
# 11807  The Kepler Mission has found thousands of plan...      0
# 11779  The solar system started to form about 4.56 Gy...      0
# 11806  One longstanding mystery in bio-evolution sinc...      0
# 11805  Instabilities in planetary systems can result ...      0
# 11804  The potential habitability of a terrestrial pl...      0
# 11803  A number of problems in probability and statis...      0
# 11802  Investigating genomic structural variants at b...      0
# 11801  We present an analysis of the starspots on the...      0
# 11800  We study the interaction between the atmospher...      0
# 11797  We present the thermal evolution and emergent ...      0
# 11796  We investigate the chemical stability of CO<SU...      0
# 11795  Limb darkening is fundamental in determining t...      0
# 11794  The spectral resolution of a dispersive spectr...      0
# 11793  We analysed an extended time series of high-re...      0
# 11791  The Kepler mission results indicate that syste...      0
# 11789  We develop a chemical evolution model to study...      0
# 11787  Power-law tails are often seen in probability ...      0
# 11786  We propose an improved method for the atmosphe...      0
# 11784  We investigate the possibility of constraining...      0
# 11783  Exoplanets orbiting close to their parent star...      0
# 11780  We present results from ab initio simulations ...      0
# 29744  The ratio XA =- A (CH4 `--. H3) /A (H2 H H3) o...      0
#
# [29745 rows x 4 columns]

# %%
dfExoplanets['abstract'].iloc[19]
# Out:
# 'We investigate the role that planet detection order plays in the Kepler planet detection pipeline. The Kepler pipeline typically detects planets in order of descending signal strength (MES). We find that the detectability of transits experiences an additional 5.5 per cent and 15.9 per cent efficiency loss, for periods &lt;200 days and &gt;200 days respectively, when detected after the strongest signal transit in a multiple-planet system. We provide a method for determining the transit probability for multiple-planet systems by marginalizing over the empirical Kepler dataset. Furthermore, because detection efficiency appears to be a function of detection order, we discuss the sorting statistics that affect the radius and period distributions of each detection order. Our occurrence rate dataset includes radius measurement updates from the California Kepler Survey (CKS), Gaia DR2, and asteroseismology. Our population model is consistent with the results of Burke et al. (2015), but now includes an improved estimate of the multiplicity distribution. From our obtained model parameters, we find that only 4.0± 4.6{{ per cent}} of solar-like GK dwarfs harbour one planet. This excess is smaller than prior studies and can be well modelled with a modified Poisson distribution, suggesting that the Kepler Dichotomy can be accounted for by including the effects of multiplicity on detection efficiency. Using our modified Poisson model, we expect the average number of planets is 5.86 ± 0.18 planets per GK dwarf within the radius and period parameter space of Kepler.'

# %%
abstract=str(dfS['abstract'].iloc[35])
abstract
# Out:
# 'Most massive stars, if not all, are in binary configuration or higher multiples. These massive stars undergo supernova explosions and end their lives as either black holes or neutron stars. Recent observations have suggested that neutron stars and perhaps even black holes receive large velocity kicks at birth. Such natal kicks and the sudden mass loss can significantly alter the orbital configuration of the system. Here we derive general analytical expressions that describe the effects of natal kicks in binaries on hierarchical triple systems. We explore several proof-of-concept applications such as black hole and neutron stars binaries and X-ray binaries with either stellar or Supermassive Black Hole (SMBH) companions on a wide orbit. Kicks can disrupt the hierarchical configuration, although it is harder to escape the potential well of an SMBH. Some binary systems do escape the SMBH system resulting in hyper-velocity binary system. Furthermore, kicks can result in increasing or decreasing the orbital separations. Decreasing the orbital separation may have significant consequences in these astrophysical systems. For example, shrinking the separation post-supernova kick can lead to the shrinking of an inner compact binary that then may merge via Gravitational Wave (GW) emission. This process yields a supernova that is shortly followed by a possible GW-LIGO event. Interestingly, we find that the natal kick can result in shrinking the outer orbit, and the binary may cross the tertiary Roche limit, breaking up the inner binary. Thus, in the case of SMBH companion, this process can lead to either a tidal disruption event or a GW-LISA detection event (Extreme Mass ratio inspiral, EMRI) with a supernova precursor.'

# %%
suchgruppe=["detect","discover","find"]
suchbegriff="FALSE"
for i in suchgruppe:
    suchbegriff=suchbegriff+"|"+i
suchbegriff
# Out:
# 'FALSE|detect|discover|find'

# %%
dfExoplanets["count"]=dfExoplanets["abstract"].str.count(suchbegriff,re.I)

# %%
dfExoplanets.sort_values(by=["count"],ascending=False)
# Out:
#                                                    title  year  \
# 12471                    The Kepler False Positive Table  2015
# 9035                              AAS 228: Day 3 morning  2016
# 28152                           Fourteen Times the Earth  2004
# 28254     Two Extremely Hot Exoplanets Caught in Transit  2004
# 15606  Searching for transits in the WTS with the dif...  2013
# 29292                    Exoplanets: The Hunt Continues!  2001
# 11600  Robust high-contrast companion detection from ...  2015
# 23700                            32 New Exoplanets Found  2009
# 10122                   Disk Detective Follow-Up Program  2016
# 29430                                 Exoplanets Galore!  2000
# 23019  An a Priori Investigation of Astrophysical Fal...  2010
# 27658  Comparative blind test of five planetary trans...  2005
# 6421      Microlensing Discovery of an Earth-Mass Planet  2017
# 13897  A near-infrared SETI experiment: probability d...  2014
# 21898                                         Exoplanets  2010
# 12122  Detecting stars, galaxies, and asteroids with ...  2015
# 22906               Turning Planetary Theory Upside Down  2010
# 29034  Book Review: Distant wanderers / Copernicus Bo...  2002
# 29409  Youngest Brown Dwarf Yet in a Multiple Stellar...  2000
# 22012  Planet from another galaxy discovered - Galact...  2010
# 5585   Detector with internal gain for short-wave inf...  2017
# 4402   Characterization of Exoplanets and Stellar Sys...  2018
# 7310   Development of an Ultra-Stable Mid-Infrared De...  2017
# 13226  Extrasolar planets detections and statistics t...  2014
# 29269  NTT Observations Indicate that Brown Dwarfs Fo...  2001
# 2138   K-Stacker: Keplerian image recombination for t...  2018
# 24227                  Lightest exoplanet yet discovered  2009
# 7632   Radial Velocity Fiber-Fed Spectrographs Toward...  2016
# 9040                              AAS 228: Day 1 morning  2016
# 2377                        The Ladder of Life Detection  2018
# ...                                                  ...   ...
# 17333               The French-Italian Concordia Station  2013
# 4923   The Light Source Problem: The Effect of Hetero...  2017
# 17309  Progress and Results from the Chinese Small Te...  2013
# 17295  Shape, density, and geology of the nucleus of ...  2013
# 17297  Magnetic Activity Cycles in the Exoplanet Host...  2013
# 4932   Optical design of the WFIRST Phase-A Integral ...  2017
# 17299  A distribution of large particles in the coma ...  2013
# 4931   An assessment of some closed-form expressions ...  2017
# 17301  Effects of Dust Growth and Settling on the Ion...  2013
# 17302  Mini-Oort clouds: compact isotropic planetesim...  2013
# 17303  The SCAR Astronomy &amp; Astrophysics from Ant...  2013
# 17304  Dust environment predictions for the ESA L-cla...  2013
# 17305  SONG China project - participating in the glob...  2013
# 4929                                 The COROT telescope  2017
# 4928   Erratum for "Symmetry of stochastic non-variat...  2017
# 4927   Static and dynamic micro deformable mirror cha...  2017
# 4924   The afocal telescope optical design and tolera...  2017
# 17311     Statistical Analysis of Multiplanetary Systems  2013
# 17312  A European vision for a ``Polar Large Telescop...  2013
# 17313  Updates to the Exoplanet Orbit Database and Tr...  2013
# 17314          Optical Interferometry from the Antarctic  2013
# 17315           The polarimeters for HARPS and X-shooter  2013
# 17321  Probing for Exoplanets Hiding in Dusty Debris ...  2013
# 17322  Performance of the SDSS-III MARVELS New Data P...  2013
# 17323  A uniform treatment of the orbital effects due...  2013
# 17325  Calibration of the Kepler Public Data for Aste...  2013
# 17326  An analysis of CoRoT multicolour photometry of...  2013
# 17327  Modeling the onset of photosynthesis after the...  2013
# 17329  The State Of The Art For Ground-Based Transit ...  2013
# 29744  The Importance of Methane to Pressure-Induced ...  1971
#
#                                                 abstract  count
# 12471  The Kepler Space Telescope has detected thousa...     22
# 9035   Editors Note:This week were at the 228th AAS M...     20
# 28152  ESO HARPS Instrument Discovers Smallest Ever E...     18
# 28254  VLT Measures Properties of New Jupiter-Size Ob...     17
# 15606  The search for exo-planets is currently one of...     17
# 29292  Swiss Telescope at La Silla Very Successful Su...     17
# 11600  Context. Long-baseline interferometry is an im...     16
# 23700  oday, at an international ESO/CAUP exoplanet c...     16
# 10122  As new data on exoplanets and young stellar as...     16
# 29430  Eight New Very Low-Mass Companions to Solar-Ty...     16
# 23019  Astrophysical false positives due to stellar e...     15
# 27658  Because photometric surveys of exoplanet trans...     15
# 6421   What do we know about planet formation around ...     15
# 13897  A Search for Extraterrestrial Life (SETI), bas...     15
# 21898  This is a unique time in human history - for t...     15
# 12122  Context. Gaia is Europe's space astrometry mis...     14
# 22906  The discovery of nine new transiting exoplanet...     14
# 29034  Are we alone in the Universe? The Earth, teemi...     14
# 29409  ... and the Sharpest Optical Image (0.18 arcse...     14
# 22012  An exoplanet orbiting a star that entered our ...     14
# 5585   &lt;title&gt;Abstarct.Highly sensitive photon ...     14
# 4402   Large astronomical surveys find thousands of i...     14
# 7310   The discovery of the Trappist-1 system, which ...     14
# 13226  Gravitational microlensing was proposed thirty...     14
# 29269  Dusty Disks Detected around Very Young Substel...     14
# 2138   Context. Angular differential imaging (ADI) ta...     13
# 24227  Well-known exoplanet researcher Michel Mayor t...     13
# 7632   This thesis is developed in the framework of t...     13
# 9040   Editors Note:This week were at the 228th AAS M...     13
# 2377   Life detection includes measurements seeking t...     13
# ...                                                  ...    ...
# 17333  Concordia is a French-Italian permanent statio...      0
# 4923   TESS will soon enable the study of terrestrial...      0
# 17309  In 2008 January the 24th Chinese expedition te...      0
# 17295  Data from the Extrasolar Planet Observation an...      0
# 17297  The active K2 dwarf epsilon Eri has been exten...      0
# 4932   WFIRST is one of NASA's Decadal Survey Mission...      0
# 17299  The coma of Comet 103P/Hartley 2 has a signifi...      0
# 4931   Rational approximations for the Gauss function...      0
# 17301  We investigate the evolution of the ionization...      0
# 17302  Starting from planetary systems with three gia...      0
# 17303  SCAR, the Scientific Committee on Antarctic Re...      0
# 17304  We analyse the impacts of dust particles of ra...      0
# 17305  SONG (Stellar Observations Network Goup) is a ...      0
# 4929   The COROT telescope, of which the customer is ...      0
# 4928   In my recent paper [1], due to a regrettable a...      0
# 4927   The micro-opto-electro-mechanical systems (MOE...      0
# 4924   ARIEL (Atmospheric Remote-sensing Infrared Exo...      0
# 17311  In order to better understand the process of p...      0
# 17312  The Polar Large Telescope (PLT) project is pri...      0
# 17313  We report a series of updates and enhancements...      0
# 17314  The unique atmospheric conditions which pertai...      0
# 17315  Spectropolarimetry enables observations of ste...      0
# 17321  Spatially resolved images of light-scattering ...      0
# 17322  As one of the four surveys in the SDSS-III pro...      0
# 17323  We consider a binary system made of self-gravi...      0
# 17325  The Kepler mission is devoted to the search of...      0
# 17326  We analysed the chromatic data of the planetar...      0
# 17327  We do a preliminary modelling of the photosynt...      0
# 17329  Transit spectroscopy using multi-object spectr...      0
# 29744  The ratio XA =- A (CH4 `--. H3) /A (H2 H H3) o...      0
#
# [29745 rows x 4 columns]

# %% [markdown]
# # Filter

# %%
filtYear= dfExoplanets['year']<2016
dfExoplanets[filtYear].head(2)
# Out:
#                                                    title  year  \
# 10224                                     Ktransit 0.2.2  2015
# 10225  Spitzer IRAC Photometry for Time Series in Cro...  2015
#
#                                                 abstract  count
# 10224  A simple exoplanet transit modeling tool in py...      0
# 10225  We develop a new photometry algorithm that is ...      0

# %% [markdown]
# # Groups

# %%
dfYear=dfExoplanets.groupby("year").size().reset_index(name="counts")
dfYear.tail(5)
# Out:
#     year  counts
# 38  2015    2629
# 39  2016    2851
# 40  2017    2866
# 41  2018    3930
# 42  2019     577

# %%
dfYear=dfYear.drop(42)

# %% [markdown]
# # Visualisation

# %%
plt.bar(dfYear["year"],dfYear["counts"], color='orange')
plt.xlabel("Jahr")
plt.ylabel("Anzahl")
plt.title('Publikation')
plt.show()

# %%
dfYear2=dfS.groupby("year").size().reset_index(name="counts")
dfYear2=dfYear2.drop(22)
dfYear2.tail(5)
# Out:
#     year  counts
# 32  2015     862
# 33  2016     928
# 34  2017     859
# 35  2018    1251
# 36  2019     223

# %%
plt.bar(dfYear["year"],dfYear["counts"], color='orange')
plt.bar(dfYear2["year"],dfYear2["counts"], color='blue')
plt.xlabel("Jahr")
plt.ylabel("Anzahl")
plt.title('Publikation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-64461179aea4> in <module>()
# ----> 1 plt.bar(dfYear["year"],dfYear["counts"], color='orange')
#       2 plt.bar(dfYear2["year"],dfYear2["counts"], color='blue')
#       3 plt.xlabel("Jahr")
#       4 plt.ylabel("Anzahl")
#       5 plt.title('Publikation')
#
# NameError: name 'plt' is not defined

# %%
df.to_pickle("c:/Dropbox/temp/df_nasa.pcl")
