# %% [markdown]
# # Extracting Headings from the Publications about Exoplanets in ArXiv

# %% [markdown]
# ## Loading the packages

# %%
import pandas as pd
import re
import bs4 as bs
from collections import *

# %% [markdown]
# ## Loading the dataframe into python

# %% [markdown]
# Here it is important to include the statement orient = 'table', because this dataframe was exported with this option, so that the exported json is a valid json. The head of the dataframe is printed out.

# %%
dfExoplanets = pd.read_json('./data/dfExoplanetsArxiv_v1.json', orient = 'table')
dfExoplanets = dfExoplanets[['authors','title','abstract','xmlpath']]
dfExoplanets = dfExoplanets[dfExoplanets.xmlpath != 'None']
dfExoplanets['xmlpath'] = [i.replace('..', '.').replace('xml/', '') for i in dfExoplanets.xmlpath]

# %%
dfExoplanets.head()
# Out:
#                                              authors  \
# 0                               [Gerard R. Lemaitre]
# 1  [R. Poleski, B. S. Gaudi, Xiaojia Xie, A. Udal...
# 2  [L. Affer, M. Damasso, G. Micela, E. Poretti, ...
# 3  [B. Fuhrmeister, S. Czesla, J. H. M. M. Schmit...
# 4  [Gabriel A. Caceres, Eric D. Feigelson, G. Jog...
#
#                                                title  \
# 0  Active Optics in Astonomy - Modeling of freefo...
# 1        A Wide Orbit Exoplanet OGLE-2012-BLG-0838Lb
# 2  HADES RV programme with HARPS-N at TNG. X. A s...
# 3  The CARMENES search for exoplanets around M dw...
# 4          AutoRegressive Planet Search: Methodology
#
#                                             abstract  \
# 0  Active optics techniques on large telescopes a...
# 1  We present the discovery of a planet on a very...
# 2  The HArps-n red Dwarf Exoplanet Survey is prov...
# 3  We use spectra from CARMENES, the Calar Alto h...
# 4  The detection of periodic signals from transit...
#
#                              xmlpath
# 0  ./data/paper/1901/05650v1.tei.xml
# 1  ./data/paper/1901/05466v1.tei.xml
# 2  ./data/paper/1901/05338v1.tei.xml
# 3  ./data/paper/1901/05173v1.tei.xml
# 4  ./data/paper/1901/05116v1.tei.xml

# %% [markdown]
# ## Extracting headings of papers

# %% [markdown]
# This method uses Beautiful Soup and searches through the whole xml.

# %%
def findHeadingsXML(soup):
    try:
        heading = []
        for bodies in soup.find_all('body'):
            for div in bodies.find_all('div'):
                for heads in div.find_all('head'):
                    heading.append(heads.text)
    except:
        heading = []
    return heading

# %% [markdown]
# Executing of definition:

# %%
headinglist = []
for i in dfExoplanets.xmlpath:
    infile = open(i, "r", encoding="utf8")
    contents = infile.read()
    soup = bs.BeautifulSoup(contents,'xml')

    headinglist.append(findHeadingsXML(soup))

# %% [markdown]
# Appending the list of headings to the dataframe as a new column and showing the head of the new dataframe:

# %%
dfExoplanets['headings'] = headinglist

# %%
dfExoplanets.head()
# Out:
#                                              authors  \
# 0                               [Gerard R. Lemaitre]
# 1  [R. Poleski, B. S. Gaudi, Xiaojia Xie, A. Udal...
# 2  [L. Affer, M. Damasso, G. Micela, E. Poretti, ...
# 3  [B. Fuhrmeister, S. Czesla, J. H. M. M. Schmit...
# 4  [Gabriel A. Caceres, Eric D. Feigelson, G. Jog...
#
#                                                title  \
# 0  Active Optics in Astonomy - Modeling of freefo...
# 1        A Wide Orbit Exoplanet OGLE-2012-BLG-0838Lb
# 2  HADES RV programme with HARPS-N at TNG. X. A s...
# 3  The CARMENES search for exoplanets around M dw...
# 4          AutoRegressive Planet Search: Methodology
#
#                                             abstract  \
# 0  Active optics techniques on large telescopes a...
# 1  We present the discovery of a planet on a very...
# 2  The HArps-n red Dwarf Exoplanet Survey is prov...
# 3  We use spectra from CARMENES, the Calar Alto h...
# 4  The detection of periodic signals from transit...
#
#                              xmlpath  \
# 0  ./data/paper/1901/05650v1.tei.xml
# 1  ./data/paper/1901/05466v1.tei.xml
# 2  ./data/paper/1901/05338v1.tei.xml
# 3  ./data/paper/1901/05173v1.tei.xml
# 4  ./data/paper/1901/05116v1.tei.xml
#
#                                             headings
# 0  [Introduction, Optical design with a reflectiv...
# 1  [INTRODUCTION, EPOXI imaging, VVV photometry, ...
# 2  [INTRODUCTION, STELLAR PROPERTIES OF Gl 686, D...
# 3  [Introduction, Observations and data reduction...
# 4  [INTRODUCTION, AUTOREGRESSIVE MODELING, Overvi...

# %% [markdown]
# ## Count the headings

# %%
listHeadings = [item for sublist in headinglist for item in sublist]
listHeadings = [i.lower().replace('&', 'and') for i in listHeadings]
countHeadings = dict(Counter([i for i in listHeadings if len(i) > 3 and not re.search('[^a-zA-Z\s]', i)]))
countHeadings = OrderedDict(sorted(countHeadings.items(), key=lambda x: x[1], reverse = True))

# %%
countHeadings
# Out:
# OrderedDict([('introduction', 3730),
#              ('conclusions', 1177),
#              ('discussion', 1147),
#              ('results', 915),
#              ('conclusion', 613),
#              ('observations', 416),
#              ('summary', 410),
#              ('observations and data reduction', 241),
#              ('methods', 197),
#              ('discussion and conclusions', 184),
#              ('summary and conclusions', 170),
#              ('luvoir', 168),
#              ('results and discussion', 164),
#              ('analysis', 163),
#              ('data reduction', 135),
#              ('summary and discussion', 125),
#              ('acknowledgments', 118),
#              ('method', 112),
#              ('appendix', 108),
#              ('data analysis', 98),
#              ('parameter', 96),
#              ('stellar parameters', 81),
#              ('discussion and conclusion', 81),
#              ('acknowledgements', 77),
#              ('model', 77),
#              ('overview', 69),
#              ('data', 66),
#              ('photometry', 64),
#              ('methodology', 52),
#              ('stellar properties', 50),
#              ('model description', 49),
#              ('radial velocities', 47),
#              ('concluding remarks', 43),
#              ('background', 42),
#              ('light curve analysis', 41),
#              ('target selection', 40),
#              ('observations and data analysis', 40),
#              ('models', 39),
#              ('summary and conclusion', 37),
#              ('simulations', 36),
#              ('the model', 35),
#              ('initial conditions', 34),
#              ('stellar activity', 33),
#              ('spectroscopy', 31),
#              ('astrometry', 31),
#              ('system parameters', 31),
#              ('future work', 30),
#              ('exoplanets', 30),
#              ('conclusions and discussion', 30),
#              ('spectroscopic observations', 30),
#              ('star', 30),
#              ('discussion and summary', 29),
#              ('future prospects', 29),
#              ('analysis and results', 27),
#              ('radiative transfer', 27),
#              ('name', 26),
#              ('planet', 26),
#              ('wfirst', 26),
#              ('metallicity', 25),
#              ('key requirements', 24),
#              ('transmission spectrum', 23),
#              ('spectroscopic analysis', 23),
#              ('references', 23),
#              ('radial velocity', 22),
#              ('theory', 22),
#              ('eccentricity', 22),
#              ('applications', 22),
#              ('optical design', 21),
#              ('boundary conditions', 21),
#              ('sample selection', 21),
#              ('transits', 21),
#              ('the science program', 21),
#              ('transmission spectra', 21),
#              ('discussions', 21),
#              ('microlensing', 21),
#              ('the role of luvoir', 20),
#              ('observations and analysis', 20),
#              ('transit timing variations', 19),
#              ('planetary parameters', 19),
#              ('discuss this topic', 18),
#              ('stellar variability', 18),
#              ('performance', 18),
#              ('photometric observations', 18),
#              ('motivation', 17),
#              ('spectral analysis', 17),
#              ('data reduction and analysis', 17),
#              ('wavelength calibration', 17),
#              ('parameters', 17),
#              ('clouds', 17),
#              ('light curves', 17),
#              ('uncertainties', 17),
#              ('modelling', 16),
#              ('summary and outlook', 16),
#              ('numerical results', 16),
#              ('conclusions and future work', 16),
#              ('transit timing', 16),
#              ('planets', 16),
#              ('planet occurrence', 16),
#              ('photometric detection', 15),
#              ('observation', 15),
#              ('observational data', 15),
#              ('model selection', 15),
#              ('simulation results', 15),
#              ('numerical simulations', 15),
#              ('direct imaging', 15),
#              ('observational constraints', 15),
#              ('abstract', 15),
#              ('limb darkening', 15),
#              ('implementation', 14),
#              ('materials and methods', 14),
#              ('stellar characteristics', 14),
#              ('the future', 14),
#              ('summary and future work', 14),
#              ('mechanical design', 14),
#              ('atmospheric model', 14),
#              ('opacities', 14),
#              ('determination of system parameters', 14),
#              ('conclusions and perspectives', 14),
#              ('observing strategy', 14),
#              ('approach', 14),
#              ('context', 14),
#              ('spectra', 14),
#              ('transit parameters', 14),
#              ('reconnaissance spectroscopy', 14),
#              ('interferometric observations', 14),
#              ('habitability', 13),
#              ('atmospheric models', 13),
#              ('forward model', 13),
#              ('detection limits', 13),
#              ('simulation setup', 13),
#              ('setup', 13),
#              ('photometric analysis', 13),
#              ('sample', 13),
#              ('comparison with observations', 13),
#              ('transiting planets', 13),
#              ('modeling', 13),
#              ('kepler photometry', 13),
#              ('radial velocity measurements', 13),
#              ('atmospheric escape', 12),
#              ('global modeling of the data', 12),
#              ('mass', 12),
#              ('kinematics', 12),
#              ('light curve modeling', 12),
#              ('transit fitting', 12),
#              ('numerical methods', 12),
#              ('calibration', 12),
#              ('transmission spectroscopy', 12),
#              ('stellar rotation', 12),
#              ('observations and reduction', 12),
#              ('surface gravity', 12),
#              ('model validation', 12),
#              ('observation and data reduction', 12),
#              ('outlook', 12),
#              ('instrument', 12),
#              ('doppler observations and keplerian fit', 12),
#              ('asteroseismology', 11),
#              ('wavelength dependence', 11),
#              ('eclipsing binaries', 11),
#              ('properties of the parent star', 11),
#              ('excluding blend scenarios', 11),
#              ('radial velocity observations', 11),
#              ('comparison with previous studies', 11),
#              ('executive summary', 11),
#              ('limitations', 11),
#              ('the large uv optical infrared surveyor', 11),
#              ('imaging', 11),
#              ('statistical analysis', 11),
#              ('basic equations', 11),
#              ('jupiter', 11),
#              ('results and analysis', 11),
#              ('model atmospheres', 11),
#              ('light curve fitting', 11),
#              ('targets', 11),
#              ('orbital parameters', 11),
#              ('spectrograph', 11),
#              ('corot observations', 11),
#              ('atmospheric parameters', 10),
#              ('transit model', 10),
#              ('the sample', 10),
#              ('physical parameters', 10),
#              ('numerical method', 10),
#              ('transit detection', 10),
#              ('false positives', 10),
#              ('telescope', 10),
#              ('priors', 10),
#              ('atmosphere', 10),
#              ('spectral classification', 10),
#              ('candidate selection', 10),
#              ('assumptions', 10),
#              ('results and conclusions', 10),
#              ('secondary eclipse', 10),
#              ('photometric calibration', 9),
#              ('polarimetry', 9),
#              ('equations of motion', 9),
#              ('model setup', 9),
#              ('stellar sample', 9),
#              ('spectroscopic parameters', 9),
#              ('brown dwarfs', 9),
#              ('data preparation', 9),
#              ('atmospheric composition', 9),
#              ('mars', 9),
#              ('acknowledgement', 9),
#              ('residuals', 9),
#              ('implications', 9),
#              ('chemistry', 9),
#              ('detectability', 9),
#              ('requirements', 9),
#              ('detectors', 9),
#              ('stellar models', 9),
#              ('parameter estimation', 9),
#              ('chromospheric activity', 9),
#              ('design', 9),
#              ('caveats', 9),
#              ('the data', 9),
#              ('numerical model', 9),
#              ('sensitivity', 9),
#              ('results and discussions', 9),
#              ('abundances', 9),
#              ('model parameters', 9),
#              ('clouds and hazes', 9),
#              ('data analysis and results', 9),
#              ('comparison with previous results', 9),
#              ('numerical setup', 9),
#              ('the habitable zone', 9),
#              ('photometric precision', 9),
#              ('photochemistry', 9),
#              ('data processing', 9),
#              ('physical properties', 9),
#              ('bayesian analysis', 9),
#              ('psf subtraction', 9),
#              ('noise model', 9),
#              ('tidal evolution', 9),
#              ('interpretation', 9),
#              ('transit ephemeris', 9),
#              ('gravitational microlensing', 9),
#              ('orbital solutions', 8),
#              ('ellipsoidal variations', 8),
#              ('model assumptions', 8),
#              ('sensitivity analysis', 8),
#              ('data acquisition', 8),
#              ('conclusions and outlook', 8),
#              ('population synthesis', 8),
#              ('atmospheric retrieval', 8),
#              ('phase curves', 8),
#              ('model comparison', 8),
#              ('radial velocity data', 8),
#              ('photometric variations', 8),
#              ('limitations of the model', 8),
#              ('comparison to previous work', 8),
#              ('target sample', 8),
#              ('code availability', 8),
#              ('temperature', 8),
#              ('solar system', 8),
#              ('effective temperatures', 8),
#              ('extended data', 8),
#              ('orbit', 8),
#              ('orbital eccentricity', 8),
#              ('star spots', 8),
#              ('nirspec', 8),
#              ('spectral extraction', 8),
#              ('tidal heating', 8),
#              ('observational requirements', 8),
#              ('characterization', 8),
#              ('completeness', 8),
#              ('stellar abundances', 8),
#              ('composition', 8),
#              ('observations and data', 8),
#              ('coronagraph', 8),
#              ('evolution', 8),
#              ('polarization', 8),
#              ('epoch', 8),
#              ('software', 8),
#              ('type i migration', 8),
#              ('variable stars', 8),
#              ('classification', 7),
#              ('deformable mirrors', 7),
#              ('transit probability', 7),
#              ('simulated observations', 7),
#              ('observational considerations', 7),
#              ('planetary system parameters', 7),
#              ('conclusion and perspectives', 7),
#              ('jupiter and saturn', 7),
#              ('algorithm', 7),
#              ('photometric measurements', 7),
#              ('system', 7),
#              ('aperture photometry', 7),
#              ('radial velocity analysis', 7),
#              ('experimental setup', 7),
#              ('conclusion and future work', 7),
#              ('analysis and discussion', 7),
#              ('spectroscopic data', 7),
#              ('quantity', 7),
#              ('rotation periods', 7),
#              ('formalism', 7),
#              ('electrical design', 7),
#              ('disequilibrium chemistry', 7),
#              ('stellar spectra', 7),
#              ('bayesian inference', 7),
#              ('performance metrics', 7),
#              ('molecular abundances', 7),
#              ('stellar radius', 7),
#              ('conclusions and future prospects', 7),
#              ('validation', 7),
#              ('individual systems', 7),
#              ('variability', 7),
#              ('photoevaporation', 7),
#              ('list of figures', 7),
#              ('model spectra', 7),
#              ('radiative transfer model', 7),
#              ('hot jupiter', 7),
#              ('spectral types', 7),
#              ('stellar mass and radius', 7),
#              ('miri', 7),
#              ('appendices', 7),
#              ('derivation', 7),
#              ('stellar ages', 7),
#              ('observations and photometry', 7),
#              ('thermal emission', 7),
#              ('supernovae', 7),
#              ('optical spectroscopy', 7),
#              ('defining planet samples', 7),
#              ('telluric correction', 7),
#              ('observations and results', 7),
#              ('fitting procedure', 7),
#              ('principle', 7),
#              ('detection', 7),
#              ('metrology', 7),
#              ('error analysis', 7),
#              ('planet parameters', 7),
#              ('application to exoplanets', 7),
#              ('hot jupiters', 7),
#              ('reduction', 7),
#              ('the method', 7),
#              ('observations and data processing', 7),
#              ('arcsec', 7),
#              ('light curve fits', 7),
#              ('orbital solution', 7),
#              ('timing', 7),
#              ('broadband', 7),
#              ('optical layout', 6),
#              ('rotation period', 6),
#              ('harps observations', 6),
#              ('flux calibration', 6),
#              ('scientific motivation', 6),
#              ('image quality', 6),
#              ('background subtraction', 6),
#              ('lightcurve analysis', 6),
#              ('detrending', 6),
#              ('synthetic observations', 6),
#              ('data selection', 6),
#              ('comparison with previous work', 6),
#              ('atmospheric chemistry', 6),
#              ('emission spectra', 6),
#              ('biosignatures', 6),
#              ('equation of state', 6),
#              ('computational methods', 6),
#              ('stellar flux', 6),
#              ('spectral type', 6),
#              ('dynamics', 6),
#              ('convection', 6),
#              ('light curve modelling', 6),
#              ('comparison with previous works', 6),
#              ('kepler light curves', 6),
#              ('preliminary results', 6),
#              ('atmospheric properties', 6),
#              ('science case', 6),
#              ('titan', 6),
#              ('dark current', 6),
#              ('photometry and astrometry', 6),
#              ('transit photometry', 6),
#              ('giant planets', 6),
#              ('planet formation', 6),
#              ('outline', 6),
#              ('simulated data', 6),
#              ('population synthesis method', 6),
#              ('examples', 6),
#              ('eccentric orbits', 6),
#              ('recommendations', 6),
#              ('current status', 6),
#              ('application', 6),
#              ('doppler boosting', 6),
#              ('adaptive optics imaging', 6),
#              ('physical model', 6),
#              ('comparison with literature', 6),
#              ('orbital models', 6),
#              ('reflected light', 6),
#              ('wavefront control', 6),
#              ('transit search', 6),
#              ('optical depth', 6),
#              ('object', 6),
#              ('flares', 6),
#              ('chemical composition', 6),
#              ('model fitting', 6),
#              ('kepler observations', 6),
#              ('correlated noise', 6),
#              ('rotational period', 6),
#              ('equilibrium chemistry', 6),
#              ('tidal effects', 6),
#              ('measurements', 6),
#              ('stellar and planetary parameters', 6),
#              ('oxygen', 6),
#              ('eccentricities', 6),
#              ('period', 6),
#              ('kepler data', 6),
#              ('fundamental parameters', 6),
#              ('uranus and neptune', 6),
#              ('saturn', 6),
#              ('ttv analysis', 6),
#              ('adaptive optics', 6),
#              ('isochrones', 6),
#              ('photon noise', 6),
#              ('abundance analysis', 6),
#              ('lithium abundance', 6),
#              ('performances', 6),
#              ('kiss survey program', 6),
#              ('introduction and motivation', 6),
#              ('dynamical stability', 6),
#              ('rayleigh scattering', 6),
#              ('pueyo', 6),
#              ('errors', 6),
#              ('future developments', 6),
#              ('systematic effects', 6),
#              ('method and results', 6),
#              ('observations and reductions', 6),
#              ('stellar wind', 6),
#              ('the gaia legacy', 6),
#              ('primary transit', 6),
#              ('atmospheres of exoplanets and brown dwarfs', 6),
#              ('lithium', 6),
#              ('transit times', 6),
#              ('wavefront sensing and control', 5),
#              ('bibliography', 5),
#              ('parameter space', 5),
#              ('transit spectroscopy', 5),
#              ('host star properties', 5),
#              ('comparison to observations', 5),
#              ('data reduction pipeline', 5),
#              ('astrometric calibration', 5),
#              ('model comparisons', 5),
#              ('atmosphere model', 5),
#              ('technical description', 5),
#              ('date', 5),
#              ('hipparcos astrometry', 5),
#              ('the algorithm', 5),
#              ('orbital evolution', 5),
#              ('result', 5),
#              ('atmosphere models', 5),
#              ('mcmc analysis', 5),
#              ('blending', 5),
#              ('science objectives', 5),
#              ('coronagraphs', 5),
#              ('thermal', 5),
#              ('formation flying', 5),
#              ('thermal design', 5),
#              ('synthetic spectra', 5),
#              ('model inputs', 5),
#              ('transit modeling', 5),
#              ('equations of state', 5),
#              ('false positive probability', 5),
#              ('habitable zone', 5),
#              ('water', 5),
#              ('planet properties', 5),
#              ('timescales', 5),
#              ('implications for habitability', 5),
#              ('application to observations', 5),
#              ('experimental results', 5),
#              ('list of tables', 5),
#              ('conclusions and prospects', 5),
#              ('comets', 5),
#              ('structure', 5),
#              ('photometric accuracy', 5),
#              ('future directions', 5),
#              ('stellar wind model', 5),
#              ('spacecraft', 5),
#              ('spectral features', 5),
#              ('multiplicity', 5),
#              ('cloud model', 5),
#              ('expected results', 5),
#              ('detections', 5),
#              ('orbital stability', 5),
#              ('light curve extraction', 5),
#              ('chemical abundances', 5),
#              ('prospects', 5),
#              ('evolutionary status', 5),
#              ('planet mass', 5),
#              ('venus', 5),
#              ('analysis method', 5),
#              ('equations', 5),
#              ('spectral resolution', 5),
#              ('instrument performance', 5),
#              ('early earth', 5),
#              ('requirements for phase correction', 5),
#              ('energy balance', 5),
#              ('case studies', 5),
#              ('chemical model', 5),
#              ('final remarks', 5),
#              ('optics', 5),
#              ('fitting method', 5),
#              ('dissipation', 5),
#              ('summary of results', 5),
#              ('the solar system', 5),
#              ('differential rotation', 5),
#              ('general results', 5),
#              ('spitzer photometry', 5),
#              ('disk model', 5),
#              ('numerical models', 5),
#              ('reductions', 5),
#              ('sed analysis', 5),
#              ('science requirements', 5),
#              ('m dwarfs', 5),
#              ('binaries', 5),
#              ('observables', 5),
#              ('tests', 5),
#              ('instrumentation', 5),
#              ('measurement', 5),
#              ('radius', 5),
#              ('planet radius', 5),
#              ('discoveries', 5),
#              ('theoretical background', 5),
#              ('false positive analysis', 5),
#              ('dynamical analysis', 5),
#              ('timing analysis', 5),
#              ('strong lensing', 5),
#              ('integration', 5),
#              ('detecting exoplanets with gravitational microlensing', 5),
#              ('asteroseismic analysis', 5),
#              ('transit timing analysis', 5),
#              ('data acquisition and reduction', 5),
#              ('orbital analysis', 5),
#              ('observing log', 5),
#              ('ephemeris', 5),
#              ('transit analysis', 5),
#              ('observations and methods', 5),
#              ('epj web of conferences', 5),
#              ('kepler', 5),
#              ('supplementary information', 5),
#              ('core accretion', 5),
#              ('observations and analyses', 5),
#              ('superwasp photometry', 5),
#              ('terrestrial planet formation', 5),
#              ('spectrum of each planet', 5),
#              ('section summary', 5),
#              ('keplerian solution', 5),
#              ('stellar characterization', 4),
#              ('spectral energy distribution', 4),
#              ('angular differential imaging', 4),
#              ('image reduction', 4),
#              ('white light curve', 4),
#              ('instrument description', 4),
#              ('optimization', 4),
#              ('rv analysis', 4),
#              ('discovery photometry', 4),
#              ('harps data', 4),
#              ('future issues', 4),
#              ('disclosure statement', 4),
#              ('performance evaluation', 4),
#              ('correction of systematic effects', 4),
#              ('supplementary materials', 4),
#              ('stellar and planetary models', 4),
#              ('derived parameters', 4),
#              ('retrieval', 4),
#              ('system characterization', 4),
#              ('mercury', 4),
#              ('white dwarfs', 4),
#              ('disk models', 4),
#              ('tables', 4),
#              ('sky subtraction', 4),
#              ('uranus', 4),
#              ('conclusion and discussion', 4),
#              ('other considerations', 4),
#              ('instrumental setup', 4),
#              ('tess', 4),
#              ('procedure', 4),
#              ('science goals', 4),
#              ('detector', 4),
#              ('eclipse mapping', 4),
#              ('individual planets', 4),
#              ('high contrast imaging', 4),
#              ('parallax', 4),
#              ('latitudinal energy balance modelling', 4),
#              ('disk evolution', 4),
#              ('protoplanetary disks', 4),
#              ('power', 4),
#              ('communications', 4),
#              ('concept of operations', 4),
#              ('integration and test', 4),
#              ('binary stars', 4),
#              ('image analysis', 4),
#              ('the models', 4),
#              ('the code', 4),
#              ('albedo', 4),
#              ('likelihood', 4),
#              ('light curve models', 4),
#              ('experimental design', 4),
#              ('samples', 4),
#              ('data and analysis', 4),
#              ('introduction and background', 4),
#              ('nested sampling', 4),
#              ('lenslet array', 4),
#              ('initial results', 4),
#              ('model scenarios', 4),
#              ('first results', 4),
#              ('summary and concluding remarks', 4),
#              ('line bisector variations', 4),
#              ('multiple planets', 4),
#              ('image calibration', 4),
#              ('throughput', 4),
#              ('system overview', 4),
#              ('detection efficiency', 4),
#              ('contamination', 4),
#              ('circumstellar disks', 4),
#              ('interior structure', 4),
#              ('field of view', 4),
#              ('optical system', 4),
#              ('exomoons', 4),
#              ('climate model', 4),
#              ('methane', 4),
#              ('comparison to previous results', 4),
#              ('telescopes', 4),
#              ('science', 4),
#              ('lessons learned', 4),
#              ('pulsars', 4),
#              ('analytical considerations', 4),
#              ('disc evolution', 4),
#              ('stellar flares', 4),
#              ('thermal structure', 4),
#              ('opacity', 4),
#              ('spitzer', 4),
#              ('climate', 4),
#              ('property', 4),
#              ('temperature structure', 4),
#              ('effective temperature', 4),
#              ('habitable zone planets', 4),
#              ('introduction and context', 4),
#              ('bisector analysis', 4),
#              ('archean', 4),
#              ('midproterozoic', 4),
#              ('phanerozoic', 4),
#              ('data sources', 4),
#              ('objectives', 4),
#              ('masses', 4),
#              ('light curve detrending', 4),
#              ('exoplanet atmospheres', 4),
#              ('retrievals', 4),
#              ('transit identification', 4),
#              ('retrieval results', 4),
#              ('circumbinary planets', 4),
#              ('funding', 4),
#              ('speckle observations', 4),
#              ('physical interpretation', 4),
#              ('main text', 4),
#              ('wavelet analysis', 4),
#              ('temperatures', 4),
#              ('input parameters', 4),
#              ('inclination', 4),
#              ('iron', 4),
#              ('transit fits', 4),
#              ('earth', 4),
#              ('transmission spectrum model', 4),
#              ('proper motions', 4),
#              ('contrast', 4),
#              ('perspectives', 4),
#              ('carbon dioxide', 4),
#              ('time variability', 4),
#              ('mcmc', 4),
#              ('host star', 4),
#              ('acknowledgment', 4),
#              ('application to data', 4),
#              ('comparative planetology', 4),
#              ('reliability', 4),
#              ('geometry', 4),
#              ('chemical disequilibrium', 4),
#              ('biosignature aspects', 4),
#              ('spectral models', 4),
#              ('target', 4),
#              ('correction of systematics', 4),
#              ('discussions and conclusions', 4),
#              ('mechanisms', 4),
#              ('description', 4),
#              ('application to real data', 4),
#              ('period determination', 4),
#              ('cheops', 4),
#              ('observational strategy', 4),
#              ('data handling', 4),
#              ('circular isotropic apertures', 4),
#              ('rotation', 4),
#              ('model uncertainties', 4),
#              ('camera', 4),
#              ('candidates', 4),
#              ('stellar mass', 4),
#              ('numerical implementation', 4),
#              ('element', 4),
#              ('stellar luminosity', 4),
#              ('data availability', 4),
#              ('compositions', 4),
#              ('conclusion and prospects', 4),
#              ('stellar parameters from spectra', 4),
#              ('harps', 4),
#              ('cloud properties', 4),
#              ('model atmosphere', 4),
#              ('absolute magnitudes', 4),
#              ('payload', 4),
#              ('instrument design', 4),
#              ('elemental abundances', 4),
#              ('selection effects', 4),
#              ('sophie', 4),
#              ('starspots', 4),
#              ('simulation', 4),
#              ('uvw space motion', 4),
#              ('densities', 4),
#              ('imaging performance metrics', 4),
#              ('image processing', 4),
#              ('detection probabilities', 4),
#              ('laboratory results', 4),
#              ('superwasp observations', 4),
#              ('stellar age', 4),
#              ('the host stars', 4),
#              ('joint analysis', 4),
#              ('data acquisition and processing', 4),
#              ('scenarios', 4),
#              ('relative humidity', 4),
#              ('general description', 4),
#              ('asteroseismology of exoplanet host stars', 4),
#              ('signal to noise ratio', 4),
#              ('red noise estimation', 4),
#              ('test on the sun', 4),
#              ('accuracy', 4),
#              ('telluric contamination', 4),
#              ('microlensing parallax', 4),
#              ('transitional disks', 4),
#              ('correlations', 4),
#              ('adaptive optics observations', 4),
#              ('science motivation', 4),
#              ('planet search pipeline', 4),
#              ('data validation', 4),
#              ('removal of astrophysical false positives', 4),
#              ('systematic errors', 4),
#              ('transiting exoplanets', 4),
#              ('known variables', 4),
#              ('magnetic activity', 4),
#              ('basic model', 4),
#              ('albedos', 4),
#              ('parameter study', 4),
#              ('stellar astrophysics', 4),
#              ('transit ephemeris refinement', 4),
#              ('gas giants', 4),
#              ('transit light curve fits', 4),
#              ('the results', 4),
#              ('input data', 4),
#              ('tidal model', 4),
#              ('symbol expression', 4),
#              ('strategy', 4),
#              ('most photometry', 4),
#              ('speckle imaging', 4),
#              ('hot planets and cool stars', 4),
#              ('habitable planets', 4),
#              ('hot neptunes', 4),
#              ('error estimation', 4),
#              ('experiment', 4),
#              ('the tidal bulges', 4),
#              ('numerical evaluations', 4),
#              ('photometry from fairborn observatory', 4),
#              ('determination of the midtransit time', 4),
#              ('system properties', 3),
#              ('asas photometry', 3),
#              ('lightcurve fitting', 3),
#              ('astrometry and photometry', 3),
#              ('astrobiology', 3),
#              ('scintillation', 3),
#              ('selection of candidates', 3),
#              ('periodogram analysis', 3),
#              ('luminosity', 3),
#              ('range', 3),
#              ('surface pressure', 3),
#              ('planetary radius', 3),
#              ('observational consequences', 3),
#              ('variability analysis', 3),
#              ('history', 3),
#              ('orbit fitting', 3),
#              ('orbital elements', 3),
#              ('atmospheric characterization', 3),
#              ('materials and experimental methods', 3),
#              ('haze production setup', 3),
#              ('orbital period determination', 3),
#              ('results and interpretation', 3),
#              ('rv modeling', 3),
#              ('data availability statement', 3),
#              ('distribution of visits over time', 3),
#              ('filter choice', 3),
#              ('exposure constraints', 3),
#              ('other constraints', 3),
#              ('estimated time requirement', 3),
#              ('technical trades', 3),
#              ('special data processing', 3),
#              ('our approach', 3),
#              ('accretion rate', 3),
#              ('spectral analysis of the host star', 3),
#              ('density profile', 3),
#              ('additional data', 3),
#              ('definition', 3),
#              ('hipparcos', 3),
#              ('overview of results', 3),
#              ('statistical formalism', 3),
#              ('future outlook', 3),
#              ('hydrodynamical simulations', 3),
#              ('neptune', 3),
#              ('plan for paper', 3),
#              ('solving for time', 3),
#              ('high resolution spectroscopy', 3),
#              ('properties of the host star', 3),
#              ('high angular resolution imaging', 3),
#              ('future observations', 3),
#              ('secondary eclipses', 3),
#              ('highlights', 3),
#              ('abbreviations', 3),
#              ('photosynthesis', 3),
#              ('supporting information', 3),
#              ('planet population', 3),
#              ('reduction pipeline', 3),
#              ('white light curves', 3),
#              ('propulsion', 3),
#              ('attitude determination and control', 3),
#              ('state of the art', 3),
#              ('stellar multiplicity', 3),
#              ('ground system', 3),
#              ('mode amplitudes', 3),
#              ('thermal profile', 3),
#              ('the pipeline', 3),
#              ('neptunes', 3),
#              ('trends', 3),
#              ('comparison to', 3),
#              ('core accretion model', 3),
#              ('markov chain monte carlo', 3),
#              ('limb darkening coefficients', 3),
#              ('code tests', 3),
#              ('photochemistry model', 3),
#              ('proper motion', 3),
#              ('lens properties', 3),
#              ('model descriptions', 3),
#              ('atmospheric structure', 3),
#              ('high resolution spectra', 3),
#              ('exoplanet data', 3),
#              ('model construction', 3),
#              ('planet migration', 3),
#              ('the planet sample', 3),
#              ('bad pixel correction', 3),
#              ('linearity', 3),
#              ('galactic model', 3),
#              ('extinction', 3),
#              ('global circulation model', 3),
#              ('star catalog', 3),
#              ('sky background', 3),
#              ('photometric monitoring', 3),
#              ('coalescence', 3),
#              ('heating', 3),
#              ('other effects', 3),
#              ('result and discussion', 3),
#              ('this work', 3),
#              ('results of simulations', 3),
#              ('summary points', 3),
#              ('young stellar objects', 3),
#              ('synergies with other instruments', 3),
#              ('speckle nulling', 3),
#              ('wasp photometry', 3),
#              ('starlight suppression', 3),
#              ('calibration unit', 3),
#              ('electronics', 3),
#              ('kinematic analysis', 3),
#              ('exposure time calculator', 3),
#              ('differential photometry', 3),
#              ('lower boundary', 3),
#              ('data collection', 3),
#              ('retrieval analysis', 3),
#              ('rock', 3),
#              ('effective temperature and surface gravity', 3),
#              ('photochemical model', 3),
#              ('viscous evolution', 3),
#              ('comparison with kepler', 3),
#              ('occurrence rate mode', 3),
#              ('the simulations', 3),
#              ('candidate detection', 3),
#              ('coronagraph design', 3),
#              ('fourier analysis', 3),
#              ('white noise', 3),
#              ('calibration of the speckle pattern', 3),
#              ('preliminaries', 3),
#              ('stellar masses', 3),
#              ('thermal evolution', 3),
#              ('application to known exoplanets', 3),
#              ('statistical methods', 3),
#              ('statistical validation', 3),
#              ('white light curve analysis', 3),
#              ('phase curve', 3),
#              ('source properties', 3),
#              ('metallicity dependence', 3),
#              ('methods and results', 3),
#              ('implications for planet formation', 3),
#              ('rotational velocities', 3),
#              ('a brief history', 3),
#              ('geometric albedo', 3),
#              ('perspective', 3),
#              ('transit observations', 3),
#              ('molecular opacities', 3),
#              ('dynamical simulations', 3),
#              ('star selection', 3),
#              ('orbital fitting', 3),
#              ('atmospheres', 3),
#              ('binary systems', 3),
#              ('orbital migration', 3),
#              ('observational prospects', 3),
#              ('significance statement', 3),
#              ('temperature profile', 3),
#              ('planet validation', 3),
#              ('stellar model', 3),
#              ('radial velocity variations', 3),
#              ('hipparcos photometry', 3),
#              ('atmospheric evolution', 3),
#              ('the faint young sun paradox', 3),
#              ('the effect of eccentricity', 3),
#              ('data analysis method', 3),
#              ('orbital inclination', 3),
#              ('planned observations', 3),
#              ('occultations', 3),
#              ('optical', 3),
#              ('other planets', 3),
#              ('source', 3),
#              ('conclusions and future outlook', 3),
#              ('no additional transiting planets', 3),
#              ('cosmic ray correction', 3),
#              ('photometric model', 3),
#              ('interferometry', 3),
#              ('heat transport', 3),
#              ('planet models', 3),
#              ('tres', 3),
#              ('supplementary', 3),
#              ('ratio', 3),
#              ('mission duration', 3),
#              ('disc structure', 3),
#              ('transit probabilities', 3),
#              ('dynamic range', 3),
#              ('infrared photometry', 3),
#              ('transits and eclipses', 3),
#              ('conclusion and summary', 3),
#              ('observation strategy', 3),
#              ('orbital eccentricities', 3),
#              ('companion properties', 3),
#              ('the observations', 3),
#              ('thermal evolution model', 3),
#              ('performance assessment', 3),
#              ('eddy diffusion', 3),
#              ('instrumental noise', 3),
#              ('cluster membership', 3),
#              ('likelihood function', 3),
#              ('integration scheme', 3),
#              ('weak lensing', 3),
#              ('evolutionary state', 3),
#              ('scaling relations', 3),
#              ('the inverse problem', 3),
#              ('granulation', 3),
#              ('atmospheric dispersion', 3),
#              ('migration', 3),
#              ('model details', 3),
#              ('effect of temperature', 3),
#              ('code', 3),
#              ('stellar spectrum', 3),
#              ('terrestrial planets', 3),
#              ('planetary mass and radius', 3),
#              ('statistical tests', 3),
#              ('science cases', 3),
#              ('phase errors', 3),
#              ('numerical simulation', 3),
#              ('light curve parameters', 3),
#              ('binarity', 3),
#              ('masses and radii', 3),
#              ('interstellar reddening', 3),
#              ('outputs', 3),
#              ('occultation spectroscopy', 3),
#              ('practical considerations', 3),
#              ('gaia', 3),
#              ('star formation', 3),
#              ('systematics', 3),
#              ('temperature control', 3),
#              ('transit detections', 3),
#              ('sed fitting', 3),
#              ('target selection and observations', 3),
#              ('stellar spectroscopic parameters', 3),
#              ('bayesian model selection', 3),
#              ('circular polarisation', 3),
#              ('gyrochronology', 3),
#              ('stellar limb darkening', 3),
#              ('observable signatures', 3),
#              ('simulated spectra', 3),
#              ('the catalog', 3),
#              ('limitations of the analysis', 3),
#              ('observations and methodology', 3),
#              ('model results', 3),
#              ('astrometric microlensing', 3),
#              ('top level requirements', 3),
#              ('dependence on scattering properties', 3),
#              ('synthetic data', 3),
#              ...])
